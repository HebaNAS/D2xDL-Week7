# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: black;">Neural Networks</h1>
#         &nbsp;
#         <h3 style="text-align: center; font-size: 42px; line-height: 0px;">F20DL/F21DL</h3>
#         <h3 style="text-align: center; font-size: 42px;">Data Mining & Machine Learning</h3>
#         &nbsp;
#         <h3 style="text-align: center; font-size: 42px; line-height: 0px;">Dr. Heba El-Shimy</h3>
#         <h4 style="text-align: center; font-size: 36px; font-weight: 100;">Based on F20/21DL Slides on Canvas</h4>
#         <span>Code development was assisted by Claude.ai</span>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Compare with Algorithms we’ve seen so far</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • Decision Trees, kNN
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">Non-linear</span> decision boundaries
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Eager/Lazy learning
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • Perceptron, Linear Models, Naive Bayes
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">Linear</span> decision boundaries
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Error-Driven learning (<span style="color: #3274B5;">Gradient Descent</span>)
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #A62B17;">Neural Networks</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">Non-linear</span> decision boundaries
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Error-Driven learning (<span style="color: #3274B5;">Gradient Descent</span> + Chain Rule)
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Outline</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 36px;">
#         <li>What is the <span style="color: #3274B5;">XOR Problem</span>?</li>
#         <li>
#             <span style="color: #3274B5;">Multi-Layer Perceptron</span>
#             <ul>
#                 <li style="font-size: 36px;">Hidden layers</li>
#                 <li style="font-size: 36px;">Output layer</li>
#                 <li style="font-size: 36px;">Activation functions</li>
#             </ul>
#         </li>
#         <li>Why are Neural Networks so <span style="color: #3274B5;">powerful</span>?</li>
#         <li><span style="color: #A62B17;">Back-propagation</span> training algorithm</li>
#         <li>Practical issues</li>
#     </ul>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">The XOR Problem</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Boolean Algebra</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="margin-top: 40px; display: flex; flex-flow: row; justify-content: space-around;">
#         <div style="margin: 0 60px 0 60px;">
#             <h2 style="text-align: center; font-weight: 700; font-size: 36px;">AND</h2>
#             <table style="font-size: 30px;">
#                 <thead>
#                     <tr>
#                         <th>A</th>
#                         <th>B</th>
#                         <th>A·B</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>1</td>
#                         <td>1</td>
#                         <td>1</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>0</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>1</td>
#                         <td>0</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>1</td>
#                         <td>0</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <div style="margin: 0 60px 0 60px;">
#             <h2 style="text-align: center; font-weight: 700; font-size: 36px;">OR</h2>
#             <table style="font-size: 30px;">
#                 <thead>
#                     <tr>
#                         <th>A</th>
#                         <th>B</th>
#                         <th>A+B</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>1</td>
#                         <td>1</td>
#                         <td>1</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>0</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>1</td>
#                         <td>0</td>
#                         <td>1</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>1</td>
#                         <td>1</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <div style="margin: 0 60px 0 60px;">
#             <h2 style="text-align: center; font-weight: 700; font-size: 36px;">XOR</h2>
#             <table style="font-size: 30px;">
#                 <thead>
#                     <tr>
#                         <th>A</th>
#                         <th>B</th>
#                         <th>A ⊕ B</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>1</td>
#                         <td>1</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>0</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>1</td>
#                         <td>0</td>
#                         <td>1</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>1</td>
#                         <td>1</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#     </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">XOR Problem</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="margin-top: 40px; display: flex; flex-flow: row; justify-content: space-around;">
#         <div style="margin: 0 60px 0 60px;">
#             <h2 style="text-align: center; font-weight: 700; font-size: 36px;">XOR</h2>
#             <table style="font-size: 30px;">
#                 <thead>
#                     <tr>
#                         <th>A</th>
#                         <th>B</th>
#                         <th>A ⊕ B</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>1</td>
#                         <td>1</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>0</td>
#                         <td>0</td>
#                     </tr>
#                     <tr>
#                         <td>1</td>
#                         <td>0</td>
#                         <td>1</td>
#                     </tr>
#                     <tr>
#                         <td>0</td>
#                         <td>1</td>
#                         <td>1</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <div style="margin: 200px 60px 0 60px;">
#             <img src="images/arrow.png" width="80px" />
#         </div>
#         <div style="margin: 100px 60px 0 60px;">
#             <table style="font-size: 30px;">
#                 <thead>
#                     <tr>
#                         <th>\(x_1\)</th>
#                         <th>\(x_2\)</th>
#                         <th>\(y\)</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>1</td>
#                         <td>1</td>
#                         <td>-</td>
#                     </tr>
#                     <tr>
#                         <td>-1</td>
#                         <td>-1</td>
#                         <td>-</td>
#                     </tr>
#                     <tr>
#                         <td>1</td>
#                         <td>-1</td>
#                         <td>+</td>
#                     </tr>
#                     <tr>
#                         <td>-1</td>
#                         <td>1</td>
#                         <td>+</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#     </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# XOR data
X = np.array([[1, 1], [-1, -1], [1, -1], [-1, 1]])
y = np.array([-1, -1, 1, 1])

# Plot
plt.figure(figsize=(8, 6))
colors = ['red' if label == 1 else 'blue' for label in y]
markers = ['+' if label == 1 else '-' for label in y]
for i, (point, color, marker) in enumerate(zip(X, colors, markers)):
    plt.scatter(point[0], point[1], c=color, s=500, marker='${}$'.format(marker), linewidths=3)

plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.title('Linearly Inseparable (XOR) Problem', fontsize=16)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Neural Networks:</h1>
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Multi-layer Perceptrons</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Recap: Perceptron</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row-reverse; justify-content: center;">
#         <div style="width: 50%; margin-top: 1%;">
#             <img src="images/bio-inspired.png" alt="Bio-inspired Learning" />
#         </div>
#         <div style="width: 40%; margin-left: 8%;">
#             <ul style="font-size: 30px;">
#                 <li>
#                     Perceptron: single <span style="color: #3274B5;">neuron</span>
#                 </li>
#                 <li>
#                     Receives <span style="color: #3274B5;">input</span> from D-many neurons
#                 </li>
#                 <li>
#                     Each input has a <span style="color: #3274B5;">weight</span>
#                 </li>
#                 <li>
#                     Cell <span style="color: #A62B17;">sums</span> up weighted input
#                 </li>
#                 <li>
#                     Neuron <span style="color: #A62B17;">"fires"</span> if sum > 0
#                 </li>
#             </ul>
#         </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
#     </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Neural Networks: Multi-layer Perceptrons</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • We can think of neural networks as <span style="color: #A62B17;">combination</span> of <span style="color: #3274B5;">multiple perceptrons</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">Multilayer perceptron (MLP)</span>
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • Why would we want to do that?
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Discover more <span style="color: #A62B17;">complex</span> (a.k.a. non-linear) <span style="color: #3274B5;">decision boundaries</span>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Learn <span style="color: #3274B5;">combinations of features</span>
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Let’s design a 2-layer MLP</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row-reverse; justify-content: center;">
#         <div style="width: 50%; margin-top: 1%;">
#             <img src="images/mlp1.png" alt="Multi-layer Perceptron" />
#         </div>
#         <div style="width: 40%; margin-left: 8%;">
#             <ul style="font-size: 30px;">
#                 <li>
#                     Layer-2: \(\hat{y} = g(v \cdot h)\)
#                 </li>
#                 <li>
#                     Layer-1: \(h_i = f(w_i \cdot x)\)
#                 </li>
#                 <li>
#                     \(f, g\) are called activation/link functions
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             ▸ <span style="color: #A62B17;">hyperbolic tangent (\(\mathit{tanh}\))</span>
#                         </li>
#                         <li style="margin-bottom: 20px;">
#                             ▸ <span style="color: #3274B5;">Sigmoid \(\sigma = \frac{1}{e^{-x}+1}\)</span>
#                         </li>
#                         <li style="margin-bottom: 20px;">
#                             ▸ Rectified Linear Unit (ReLU)
#                         </li>
#                         <li style="margin-bottom: 20px;">
#                             ▸ Identity (usually not in Layer-1)
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     Set \(f = \mathit{tanh}, g = \mathit{identity}\)
#                 </li>
#                 <li>
#                     \(\hat{y} = \sum_{i} v_i \mathit{tanh}(w_i \cdot x) = v \cdot \mathit{tanh}(W \cdot x)\)
#                 </li>
#             </ul>
#         </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
#     </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Activation Functions</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row-reverse; justify-content: center;">
#         <div style="width: 50%; margin-top: 1%;">
#             <img src="images/mlp1.png" alt="Multi-layer Perceptron" />
#         </div>
#         <div style="width: 40%; margin-left: 8%;">
#             <ul style="font-size: 30px;">
#                 <li>
#                     Activation functions are usually <span style="color: #3274B5;">non-linear</span> functions
#                 </li>
#                 <li>
#                     Surrogates to <span style="color: #306F1D;">non-linear</span> as in the perceptron
#                 </li>
#                 <li>
#                     BUT they are <span style="color: #3274B5;">diﬀerentiable</span>!
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             ▸ <span style="color: #A62B17;">hyperbolic tangent [-1,1]</span>
#                         </li>
#                         <li style="margin-bottom: 20px;">
#                             ▸ <span style="color: #3274B5;">Sigmoid [0, 1]</span>
#                         </li>
#                     </ul>
#                 </li>
#                 <img src="images/activations.png" alt="Activation functions" />
#             </ul>
#         </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
#     </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# XOR data
X = np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]])
y_true = np.array([-1, 1, 1, -1])

# Initial weights and biases
W1 = np.array([[20, 20], [20, 20]])  # 2x2: input to hidden (Input -> Layer 1)
b1 = np.array([-10, -30])  # bias for hidden layer
v = np.array([1, -1])  # hidden to output weights (Layer 1 -> Layer 2)
b2 = -0.5  # output bias

# Forward pass
def forward(X, W1, b1, v, b2):
    z1 = X @ W1.T + b1  # hidden layer (Layer 1) pre-activation
    h1 = np.tanh(z1)  # hidden layer (Layer 1) activation
    z2 = h1 @ v + b2  # output (Layer 2) pre-activation
    y_hat = 1 / (1 + np.exp(-z2))  # output after activation (sigmoid)
    return z1, h1, z2, y_hat

# Call the forward method to perform the forward pass
z1, h1, z2, y_hat = forward(X, W1, b1, v, b2)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Create visualization
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

# Our neural network
ax = axes[0]
img = Image.open('images/mlp3.png')
ax.imshow(img)
ax.axis('off')
ax.set_title('Neural Network Architecture', fontsize=12, fontweight='bold')

# Plot 1: Input space
ax = axes[1]
colors = ['blue' if y == 0 else 'red' for y in y_true]
ax.scatter(X[:, 0], X[:, 1], c=colors, s=300, edgecolors='black', linewidth=2)
for i, (x, y) in enumerate(X):
    ax.text(x, y, f'({x},{y})', ha='center', va='center', fontsize=8, color='white', fontweight='bold')
ax.set_xlabel('$x_1$', fontsize=14)
ax.set_ylabel('$x_2$', fontsize=14)
ax.set_title('Input Space (XOR)', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_xlim(-2.1, 2.1)
ax.set_ylim(-2.1, 2.1)

# Plot 2: Hidden layer activations
ax = axes[2]
ax.scatter(h1[:, 0], h1[:, 1], c=colors, s=300, edgecolors='black', linewidth=2)
for i in range(len(h1)):
    ax.text(h1[i, 0], h1[i, 1], f'({h1[i, 0]:.1f}, {h1[i, 1]:.1f})', ha='center', va='center', fontsize=10, fontweight='bold', color='black')
ax.set_xlabel('$h_1$ (neuron 1)', fontsize=14)
ax.set_ylabel('$h_2$ (neuron 2)', fontsize=14)
ax.set_title('Hidden Layer Space', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.set_xlim(-2.1, 2.1)
ax.set_ylim(-2.1, 2.1)

# Plot 3: Decision boundary in hidden space
ax = axes[3]
xx, yy = np.meshgrid(np.linspace(-2.1, 2.1, 100), np.linspace(-2.1, 2.1, 100))
Z = v[0] * xx + v[1] * yy + b2
ax.contour(xx, yy, Z, levels=[0], colors='green', linewidths=3)
ax.contourf(xx, yy, Z, levels=[-100, 0, 100], colors=['lightblue', 'lightcoral'], alpha=0.3)
ax.scatter(h1[:, 0], h1[:, 1], c=colors, s=300, edgecolors='black', linewidth=2)
ax.set_xlabel('$h_1$', fontsize=10)
ax.set_ylabel('$h_2$', fontsize=10)
ax.set_title('Decision Boundary', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Function Approximation with Neural Networks</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #3274B5;">Problem formulation</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Set of possible instances \(X\)
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             - <span style="color: #A62B17;">Each instance \(x \in X\) is a feature vector \(x = [x_1, \ldots, x_D]\)</span>
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Unknown target function \(f: X \rightarrow Y\)
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             - <span style="color: #A62B17;">\(Y\) is binary valued {-1, +1}</span>
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Set of function hypotheses \(H: \{h \mid h : X \to Y\}\)
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             - <span style="color: #A62B17;">???</span>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #3274B5;">Input</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Training examples \(\{(x^{(1)}, y^{(1)}), \ldots, (x^{(N)}, y^{(N)})\}\) of unknown target function \(f\)
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #3274B5;">Output</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Hypothesis \(h \in H\) that best approximates function \(f\)
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-Layer Networks are Universal Function Approximators</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <p style="font-style: italic; font-size: 36px;"><span style="font-weight: bold;">Theorem:</span> Let \(F\) be a continuous function on a bounded subset of \(D\)-dimensional space. Then there exists a two-layer neural network \(\hat{F}\) with a
# finite number of hidden units that approximates \(F\) arbitrarily well. Namely, for all \(x\) in the domain of \(F\), \(|F(\mathbf{x}) - \hat{F}(\mathbf{x})| < \epsilon\)</p>
#     <p style="font-style: italic; font-size: 36px;">... or put simply, two-layer networks can <span style="color: #A62B17;">approximate</span> any function!</p>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Design Question</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • How many <span style="color: #3274B5;">hidden units</span>? How many <span style="color: #3274B5;">layers</span>?
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Inductive bias / Regularisation
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #A62B17;">More hidden units</span> yield more <span style="color: #3274B5;">complex functions</span>
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             - Overfitting
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #A62B17;">Fewer hidden units</span> requires <span style="color: #3274B5;">fewer examples</span> to train
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Training Neural Networks:</h1>
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Backpropagation</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Training Neural Networks</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row-reverse; justify-content: center;">
#         <div style="width: 50%; margin-top: 1%;">
#             <img src="images/mlp4.png" alt="Multi-layer Perceptron" />
#         </div>
#         <div style="width: 40%; margin-left: 8%;">
#            <p style="font-size: 36px;">Backpropagation algorithm =</p>
#             <p style="font-size: 36px;"><span style="color: #3274B5;">Gradient descent</span> + <span style="color: #A62B17;">Chain rule</span></p>
#         </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
#     </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">What’s our training objective?</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • We will consider the following <span style="color: #3274B5;">objective</span>
#             \[\min_{\mathbf{W},v} L(\mathbf{W}, v) = \min_{\mathbf{W},v} \sum_{n} \frac{1}{2}\left(y_n - \sum_{i} v_i \cdot f(\mathbf{w}_i \cdot \mathbf{x}_n)\right)^2\]
#             where
#             \[\hat{y}_n = \sum_{i} v_i \cdot f(\mathbf{w}_i \cdot \mathbf{x}_n)\]
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ i.e., our goal is to find parameters \(W, v\) that <span style="color: #A62B17;">minimise</span> <span style="color: #3274B5;">squared error</span>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">N examples with \(x_n, y_n\)</span>
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">What’s our training objective?</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • Other objectives are possible (exponential, logistic, etc.)
#         </li>
#         <li style="margin-bottom: 30px;">
#             • Weight regularisation
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Recap: General Gradient Descent Algorithm</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div>
#          \[
#             \begin{array}{ll}
#         \hline
#             \textbf{Algorithm: } & \text{GRADIENTDESCENT}(L(\mathbf{w}, b; \mathbf{D}), \mathbf{D}, maxIter, \eta_1, \ldots, \eta_k) \\
#             \hline
#             1: & \mathbf{w}^{(0)} \leftarrow \langle 0, 0, \ldots, 0 \rangle, b^{(0)} \leftarrow 0 \quad \text{// initialise variables we are optimising (weights vector and bias)} \\
#             2: & \textbf{for } k = 1 \ldots maxIter \textbf{ do} \\
#             3: & \quad \mathbf{g}^{(k)} \leftarrow \nabla_{w,b} L(w, b; \mathbf{D})|_{w,b^{(k-1)}} \quad \text{// compute gradient (slope of the loss) at current location} \\
#             4: & \quad \mathbf{w}^{(k)} \leftarrow \mathbf{w}^{(k-1)} - \eta^{(k)} \mathbf{g}^{(k)} \quad \text{// take a step down the gradient; update weights in the direction that reduces loss} \\
#             5: & \quad b^{(k)} \leftarrow b^{(k-1)} - \eta \frac{\partial L^{(k)}}{\partial b} \text{// update bias in the direction that reduces loss} \\
#             6: & \textbf{end for} \\
#             7: & \textbf{return}
#             \end{array}
#             \]
#     </div>
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 40%; margin-right: 9%;">
#             \[
#                 \begin{array}{ll}
#                 \textbf{Greek letters:} & \\
#                 \eta \text{ (eta)} & \text{learning rate (step size for updates)} \\
#                 \nabla \text{ (nabla)} & \text{gradient operator (takes derivative)} \\
#                 \partial & \text{partial derivative symbol} \\
#                 \\
#                 \textbf{Notation:} & \\
#                 w^{(k)} & \text{value of } w \text{ at iteration } k \\
#                 w^{(k-1)} & \text{value of } w \text{ at previous iteration} \\
#                 \langle 0, 0, \ldots, 0 \rangle & \text{vector of zeros} \\
#                 \leftarrow & \text{assignment (set equal to)} \\
#                 |_{w,b^{(k-1)}} & \text{evaluated at previous values}
#                 \end{array}
#                 \]
#         </div>
#         <div style="width: 40%; margin-left: 1%;">
#             \[
#                 \begin{array}{ll}
#                 \textbf{Variables:} & \\
#                 \mathbf{w} & \text{weights (parameters we're optimising)} \\
#                 b & \text{bias (another parameter we're optimising)} \\
#                 L & \text{loss function (measures prediction error)} \\
#                 \mathbf{D} & \text{dataset (training data)} \\
#                 \mathbf{g} & \text{gradient (direction to update parameters)} \\
#                 k & \text{iteration number (current step)} \\
#                 n & \text{index for data points} \\
#                 \end{array}
#                 \]
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of output layer weights \(v\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             The Loss Function:
#             <span style="font-size: 22px;">
#             \[
#             L(\mathbf{W}, v) = \sum_{n} \frac{1}{2}\left(y_n - \sum_{i} v_i \cdot f(\mathbf{w}_i \cdot \mathbf{x}_n)\right)^2
#             \]
#             </span>
#             Breaking this down:
#             <ul>
#                 <li>For each training example n, we compute the prediction: \(\hat{y}_n = \sum_i v_i \cdot f(w_i \cdot x_n)\)</li>
#                 <li>The error for example n is: \(e_n = y_n − \hat{y}_n\)</li>
#                 <li>The loss is: \(L = \frac{1}{2}e_n^2\)</li>
#             </ul>
#             We want to find: How does the loss change when we change the output weight \(v_i\)?<br/>
#             That is: \(\frac{\partial L}{\partial v_i}\)
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp5.png" alt="Multi-layer Perceptron" height="100" /></div>
#             <div><img src="images/sqloss.png" alt="Squared error loss function" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of output layer weights \(v\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             The Math of \(\frac{\partial L}{\partial v_i}\) (Chain Rule):
#             <span style="font-size: 22px;">
#             \[
#             \frac{\partial L}{\partial v_i} = \frac{\partial L}{\partial g} \cdot \frac{\partial g}{\partial v_i}
#             \]
#             </span>
#             <b>Part 1</b>: How does loss change with the prediction?<br/>
#             \[
#                 L = \frac{1}{2}(y_n - g)^2 = \frac{1}{2}e_n^2
#             \]
#             \[
#                 \frac{\partial L}{\partial g} = \frac{\partial L}{\partial e} \cdot \frac{\partial e}{\partial g} = (y_n - g) \cdot -1 = -(y_n - g) = -e_n
#             \]
#             We use \(g\) to represent the network output (the prediction)
#             <br/>
#             <br/>
#             <b>Part 2</b>: How does the prediction change with weight \(v_i\)?
#                 \[
#                 g = identity\left(\sum_i v_i \cdot h_{i,n}\right) = v_1 \cdot h_{1,n} + v_2 \cdot h_{2,n} + ... + v_i \cdot h_{i,n}
#                 \]
#                 \[
#                 \frac{\partial g}{\partial v_i} = h_{i,n}
#                 \]
#                 (The prediction changes by exactly \(h_{i,n}\) when we change \(v_i\) by 1)
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp5.png" alt="Multi-layer Perceptron" height="100" /></div>
#             <div><img src="images/sqloss.png" alt="Squared error loss function" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of output layer weights \(v\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             The Math of \(\frac{\partial L}{\partial v_i}\) (Chain Rule):
#             <span style="font-size: 22px;">
#             \[
#             \frac{\partial L}{\partial v_i} = \frac{\partial L}{\partial g} \cdot \frac{\partial g}{\partial v_i}
#             \]
#             </span>
#             Putting It Together:
#             \[
#             \frac{\partial L}{\partial v_i} = -e_n \cdot h_{i,n}
#             \]
#             In Vector Form:
#             \[
#             \nabla_v = -e_n \cdot \mathbf{h}_n
#             \]
#             Where \(\mathbf{h}_n = [h_{1,n}, h_{2,n}, ...]\) is the vector of hidden unit activations for example n.
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp5.png" alt="Multi-layer Perceptron" height="100" /></div>
#             <div><img src="images/sqloss.png" alt="Squared error loss function" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of output layer weights \(v\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             <b>The update rule*:</b><br/>
#             For a single example (iterative):
#             \[
#             \nabla_v = -e_n \cdot \mathbf{h}_n
#             \]
#             For all examples (batch):
#             \[
#             \nabla_v = -\sum_n e_n \cdot \mathbf{h}_n
#             \]
#             \[
#             v \leftarrow v - \eta \cdot \nabla_v
#             \]
#             * Assuming linear activation at output unit \[g = identity(\sum_i v_i \cdot h_{i,n})\]
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp5.png" alt="Multi-layer Perceptron" height="100" /></div>
#             <div><img src="images/sqloss.png" alt="Squared error loss function" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of hidden unit weights \(w_i\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             <b>The Loss Function</b><br/>
#             \[
#                 L(\mathbf{W}, v) = \frac{1}{2}\left(y - \sum_{i} v_i \cdot f(\mathbf{w}_i \cdot \mathbf{x})\right)^2 = \frac{1}{2}e^2
#             \]
#             Where the error for one example is: \(e = y - \sum_i v_i \cdot f(w_i \cdot x)\)
#             <br/>
#             <br/>
#             <b>The Math of the Chain Rule \(\frac{\partial L}{\partial \mathbf{w}_i} \)</b><br/>
#             \[
#                 \frac{\partial L}{\partial \mathbf{w}_i} = \frac{\partial L}{\partial f_i} \cdot \frac{\partial f_i}{\partial \mathbf{w}_i}
#             \]
#             In simple words: to find how the loss changes with weight \(w_i\), we need to go through the activation \(f_i\) of the hidden unit \(h_i\)
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp6.png" alt="Multi-layer Perceptron" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of hidden unit weights \(w_i\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             <b>The Math of the Chain Rule \(\frac{\partial L}{\partial \mathbf{w}_i} \)</b><br/>
#             \[
#                 \frac{\partial L}{\partial \mathbf{w}_i} = \frac{\partial L}{\partial f_i} \cdot \frac{\partial f_i}{\partial \mathbf{w}_i}
#             \]
#             <b>Part 1: How does loss change with the activation of hidden unit i?</b><br/>
#                 Let \(g = \sum_i v_i \cdot f_i\), so \(L = \frac{1}{2}(y - g)^2\)
#             \[
#                 \frac{\partial L}{\partial f_i} = \frac{\partial L}{\partial g} \cdot \frac{\partial g}{\partial f_i}
#             \]
#             \[\frac{\partial L}{\partial g}\ = -e_n\]
#             \[g = v_1 \cdot f_1 + v_2 \cdot f_2 + ... + v_i \cdot f_i\]
#             \[\frac{\partial g}{\partial f_i}\ = v_i\]
#             from previous slides on the output layer
#             \[
#                 \frac{\partial L}{\partial f_i} = -e_n \cdot v_i
#             \]
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp6.png" alt="Multi-layer Perceptron" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of hidden unit weights \(w_i\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             <b>The Math of the Chain Rule \(\frac{\partial L}{\partial \mathbf{w}_i} \)</b><br/>
#             \[
#                 \frac{\partial L}{\partial \mathbf{w}_i} = \frac{\partial L}{\partial f_i} \cdot \frac{\partial f_i}{\partial \mathbf{w}_i}
#             \]
#             <b>Part 2: How does the activation \(f_i\) change with the weight \(w_i\)?</b><br/>
#             \[
#                 \frac{\partial f_i}{\partial w_i} = \frac{\partial (w_i \cdot x)}{\partial w_i} = f'(w_i \cdot x) x
#             \]
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp6.png" alt="Multi-layer Perceptron" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of hidden unit weights \(w_i\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%; font-size: 30px;">
#             <b>Putting it together</b><br/>
#             \[
#                 \nabla_{\mathbf{w}_i} = -e_nv_i f'(\mathbf{w}_i \cdot \mathbf{x})\mathbf{x}
#             \]
#             <br/>
#             The gradient of the tanh function (\(f'\))<br/>
#             \[
#                 f'(\mathbf{w}_i \cdot \mathbf{x}) = [1 - \tanh^2(\mathbf{w}_i \cdot \mathbf{x})]
#             \]
#             <br/>
#             And since \(a_i = f(\mathbf{w}_i \cdot \mathbf{x})\), we can also write:
#             \[
#                 \nabla_{\mathbf{w}_i} = -e_nv_i (1 - tanh^2 (a_i))x
#             \]
#         </div>
#         <div style="width: 35%;">
#             <div><img src="images/mlp6.png" alt="Multi-layer Perceptron" height="100" /></div>
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Two-layer NN: Gradient of hidden unit weights \(w_i\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • Intuition
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #3274B5;">Small</span> \(e\) \(\rightarrow\) <span style="color: #A62B17;">small gradient</span>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ \(v_i\) <span style="color: #3274B5;">small</span> \(\rightarrow\) output not sensitive to activation of \(h_i\) \(\rightarrow\) <span style="color: #A62B17;">small gradient</span>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ \(v_i\) <span style="color: #3274B5;">flips sign</span> \(\rightarrow\) <span style="color: #A62B17;">gradient</span> should also <span style="color: #A62B17;">flip sign</span>
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Backprop for 2-layer Network</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-flow: column;">
#         <div style="width: 60%; margin-right: 5%;">
#             \[
#                 \begin{array}{ll}
#                 \textbf{Algorithm 25 } & \textbf{TWOLAYERNETWORKTRAIN}(\mathbf{D}, \eta, K, MaxIter) \\
#                 \hline
#                 1: & \mathbf{W} \leftarrow D \times K \text{ matrix of small random values} \quad \text{// initialize input layer weights} \\
#                 2: & v \leftarrow K\text{-vector of small random values} \quad \text{// initialize output layer weights} \\
#                 3: & \textbf{for } iter = 1 \ldots MaxIter \textbf{ do} \\
#                 4: & \quad \mathbf{G} \leftarrow D \times K \text{ matrix of zeros} \quad \text{// initialize input layer gradient} \\
#                 5: & \quad g \leftarrow K\text{-vector of zeros} \quad \text{// initialize output layer gradient} \\
#                 6: & \quad \textbf{for all } (x,y) \in \mathbf{D} \textbf{ do} \\
#                 7: & \quad\quad \textbf{for } i = 1 \text{ to } K \textbf{ do} \\
#                 8: & \quad\quad\quad a_i \leftarrow w_i \cdot x \\
#                 9: & \quad\quad\quad h_i \leftarrow \tanh(a_i) \quad \text{// compute activation of hidden unit } i \\
#                 10: & \quad\quad \textbf{end for} \\
#                 11: & \quad\quad \hat{y} \leftarrow v \cdot h \quad \text{// compute output unit} \\
#                 12: & \quad\quad e \leftarrow y - \hat{y} \quad \text{// compute error} \\
#                 13: & \quad\quad g \leftarrow g - eh \quad \text{// update gradient for output layer} \\
#                 14: & \quad\quad \textbf{for } i = 1 \text{ to } K \textbf{ do} \\
#                 15: & \quad\quad\quad \mathbf{G}_i \leftarrow \mathbf{G}_i - ev_i(1 - \tanh^2(a_i))x \quad \text{// update gradient for input layer} \\
#                 16: & \quad\quad \textbf{end for} \\
#                 17: & \quad \textbf{end for} \\
#                 18: & \quad \mathbf{W} \leftarrow \mathbf{W} - \eta\mathbf{G} \quad \text{// update input layer weights} \\
#                 19: & \quad v \leftarrow v - \eta g \quad \text{// update output layer weights} \\
#                 20: & \textbf{end for} \\
#                 21: & \textbf{return } \mathbf{W}, v
#                 \end{array}
#             \]
#         </div>
#         <div style="width: 30%;">
#             <img src="images/mlp7.png" alt="Multilayer Perceptron" />
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Issues with training</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #A62B17;">Sensitive</span> to <span style="color: #3274B5;">initialization</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Objective is <span style="color: #A62B17;">non-convex</span>, many <span style="color: #A62B17;">local optima</span>
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • In practice: start with <span style="color: #3274B5;">random values</span> rather than zeros
#             <li style="margin-bottom: 30px;">
#             • Many other <span style="color: #3274B5;">hyperparameters</span>
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Number of hidden units
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Number of hidden layers
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Gradient descent learning rate
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ Stopping criterion
#                 </li>
#             </ul>
#         </li>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Online vs Batch Update</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #3274B5;">Online</span> (aka Stochastic Gradient Descent)
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #A62B17;">Update</span> parameters after <span style="color: #3274B5;">forward-propagation</span> on every example
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • <span style="color: #3274B5;">Batch</span> (aka Mini-batch SGD)
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ <span style="color: #A62B17;">Update</span> parameters after <span style="color: #3274B5;">forward-propagation</span> on several examples
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • Stochastic Gradient Descent Variants
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ Adam, AdaGrad
#                 </li>
#             </ul>
#         </li>
#         <li style="margin-bottom: 30px;">
#             • Why?
#             <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                 <li style="margin-bottom: 20px;">
#                     ▸ More <span style="color: #3274B5;">robust</span>
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 20px;">
#                             - against <span style="color: #3274B5;">noise</span> (irrelevant features)
#                         </li>
#                         <li style="margin-bottom: 20px;">
#                             - can be seen as a form of <span style="color: #3274B5;">regularisation</span>
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     ▸ More <span style="color: #3274B5;">eﬃcient</span> (10M examples and Online? Nah…)
#                 </li>
#             </ul>
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14

# Customer Transaction Data
data = {
    'Transaction': ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10'],
    'Music Download?': ['No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes'],
    'Music Streaming?': ['Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes'],
    'Online Games': ['Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes'],
    'Output': ['Buys', 'Cancels', 'Buys', 'Cancels', 'Cancels', 'Cancels', 'Buys', 'Cancels', 'Cancels', 'Buys']
}

df = pd.DataFrame(data)
print("=" * 80)
print("CUSTOMER TRANSACTION DATA")
print("=" * 80)
print(df.to_string(index=False))
# Out:
# ...
# CUSTOMER TRANSACTION DATA
# ...
# Transaction Music Download? Music Streaming? Online Games  Output
#          T1              No              Yes          Yes    Buys
#          T2             Yes               No           No Cancels
#          T3             Yes               No          Yes    Buys
#          T4             Yes               No           No Cancels
#          T5              No              Yes           No Cancels
#          T6              No              Yes           No Cancels
#          T7              No               No          Yes    Buys
#          T8              No              Yes          Yes Cancels
#          T9             Yes              Yes           No Cancels
#         T10             Yes              Yes          Yes    Buys

# %%
# Convert Yes/No to 1/0 and Buys/Cancels to 1/0 (for regression-style loss)
vectorized_data = {
    'Transaction': ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10'],
    'Music Download?': [0, 1, 1, 1, 0, 0, 0, 0, 1, 1],
    'Music Streaming?': [1, 0, 0, 0, 1, 1, 0, 1, 1, 1],
    'Online Games': [1, 0, 1, 0, 0, 0, 1, 1, 0, 1],
    'Output': [1, 0, 1, 0, 0, 0, 1, 0, 0, 1]  # Buys=1, Cancels=0
}

df_vec = pd.DataFrame(vectorized_data)
print("\n" + "=" * 80)
print("VECTORIZED DATA")
print("=" * 80)
print("Features:")
print("  • Yes → 1")
print("  • No → 0")
print("\nClass (Output):")
print("  • Buys → 1")
print("  • Cancels → 0")
print()
print(df_vec.to_string(index=False))
# Out:
# ...
# VECTORIZED DATA
# ...
# Features:
#   • Yes → 1
#   • No → 0
#
# Class (Output):
#   • Buys → 1
#   • Cancels → 0
#
# Transaction  Music Download?  Music Streaming?  Online Games  Output
#          T1                0                 1             1       1
#          T2                1                 0             0       0
#          T3                1                 0             1       1
#          T4                1                 0             0       0
#          T5                0                 1             0       0
#          T6                0                 1             0       0
#          T7                0                 0             1       1
#          T8                0                 1             1       0
#          T9                1                 1             0       0
#         T10                1                 1             1       1

# %%
# Create feature matrix X and labels y
X = df_vec[['Music Download?', 'Music Streaming?', 'Online Games']].values
y = df_vec['Output'].values

print(f"\nFeature matrix X shape: {X.shape}")
print(f"Labels y shape: {y.shape}")
print()

# Network parameters
D = X.shape[1]  # Number of input features (3)
K = 2           # Number of hidden units
eta = 0.1      # Learning rate
MaxIter = 300   # Maximum iterations

print("=" * 80)
print("TWO-LAYER NETWORK TRAINING")
print("=" * 80)
print(f"Network architecture:")
print(f"  • Input features (D): {D}")
print(f"  • Hidden units (K): {K}")
print(f"  • Output units: 1")
print(f"  • Learning rate (η): {eta}")
print(f"  • Max iterations: {MaxIter}")
print()
# Out:
# Feature matrix X shape: (10, 3)
# Labels y shape: (10,)
#
# ...
# TWO-LAYER NETWORK TRAINING
# ...
# Network architecture:
#   • Input features (D): 3
#   • Hidden units (K): 2
#   • Output units: 1
#   • Learning rate (η): 0.1
#   • Max iterations: 300

# %%
# Initialize weights
np.random.seed(42)  # For reproducibility
W = np.random.randn(D, K) * 0.1  # D×K matrix
v = np.random.randn(K) * 0.1     # K-vector

print("Initial weights:")
print(f"  W (input to hidden) =\n{W}")
print(f"  v (hidden to output) = {v}")
print()

# Training history
history = {
    'loss': [],
    'W': [],
    'v': [],
    'predictions': []
}
# Out:
# Initial weights:
#   W (input to hidden) =
# [[ 0.04967142 -0.01382643]
#  [ 0.06476885  0.15230299]
#  [-0.02341534 -0.0234137 ]]
#   v (hidden to output) = [0.15792128 0.07674347]

# %%
# Training loop
print("=" * 80)
print("TRAINING PROGRESS")
print("=" * 80)

for iteration in range(MaxIter):
    # Initialize gradients
    G = np.zeros_like(W)  # D×K matrix for hidden layer
    g = np.zeros_like(v)  # K-vector for output layer
    
    total_loss = 0
    predictions = []
    
    # Loop over all training examples
    for idx in range(len(X)):
        x = X[idx]
        y_true = y[idx]
        
        # ===== FORWARD PASS =====
        # Compute hidden layer activations
        a = np.dot(W.T, x)  # K-vector: weighted inputs to hidden units
        h = np.tanh(a)      # K-vector: hidden activations
        
        # Compute output
        y_pred = np.dot(v, h)  # Scalar: network output
        
        # Compute error and loss
        e = y_true - y_pred
        loss = 0.5 * e**2
        total_loss += loss
        predictions.append(y_pred)
        
        # ===== BACKWARD PASS =====
        # Update output layer gradient
        g = g - e * h  # Accumulate: ∇v = -e·h
        
        # Update hidden layer gradients
        for i in range(K):
            # Gradient for hidden unit i
            grad_i = -e * v[i] * (1 - np.tanh(a[i])**2) * x
            G[:, i] = G[:, i] + grad_i
    
    # Update weights (after processing all examples-batch update)
    W = W - eta * G
    v = v - eta * g
    
    # Store history
    history['loss'].append(total_loss)
    history['W'].append(W.copy())
    history['v'].append(v.copy())
    history['predictions'].append(predictions.copy())
    
    # Print progress every 10 iterations
    if iteration % 10 == 0 or iteration == MaxIter - 1:
        avg_loss = total_loss / len(X)
        print(f"Iteration {iteration:3d}: Total Loss = {total_loss:.4f}, Avg Loss = {avg_loss:.4f}")

print()
print("=" * 80)
print("TRAINING COMPLETE")
print("=" * 80)
print(f"Final weights:")
print(f"  W (input to hidden) =\n{W}")
print(f"  v (hidden to output) = {v}")
print()
# Out:
# ...
# TRAINING PROGRESS
# ...
# Iteration   0: Total Loss = 1.9662, Avg Loss = 0.1966
# Iteration  10: Total Loss = 0.5081, Avg Loss = 0.0508
# Iteration  20: Total Loss = 0.3736, Avg Loss = 0.0374
# Iteration  30: Total Loss = 0.3718, Avg Loss = 0.0372
# Iteration  40: Total Loss = 0.3706, Avg Loss = 0.0371
# Iteration  50: Total Loss = 0.3695, Avg Loss = 0.0369
# Iteration  60: Total Loss = 0.3683, Avg Loss = 0.0368
# Iteration  70: Total Loss = 0.3668, Avg Loss = 0.0367
# Iteration  80: Total Loss = 0.3648, Avg Loss = 0.0365
# Iteration  90: Total Loss = 0.3618, Avg Loss = 0.0362
# Iteration 100: Total Loss = 0.3573, Avg Loss = 0.0357
# Iteration 110: Total Loss = 0.3504, Avg Loss = 0.0350
# Iteration 120: Total Loss = 0.3405, Avg Loss = 0.0341
# Iteration 130: Total Loss = 0.3278, Avg Loss = 0.0328
# Iteration 140: Total Loss = 0.3137, Avg Loss = 0.0314
# Iteration 150: Total Loss = 0.3000, Avg Loss = 0.0300
# Iteration 160: Total Loss = 0.2885, Avg Loss = 0.0288
# ...

# %%
# Final predictions
print("=" * 80)
print("FINAL PREDICTIONS")
print("=" * 80)
print(f"{'Transaction':<12} {'True':<6} {'Predicted':<10} {'Rounded':<8} {'Correct?'}")
print("-" * 60)

for idx in range(len(X)):
    x = X[idx]
    y_true = y[idx]
    
    # Forward pass
    a = np.dot(W.T, x)
    h = np.tanh(a)
    y_pred = np.dot(v, h)
    y_rounded = 1 if y_pred > 0.5 else 0
    correct = "✓" if y_rounded == y_true else "✗"
    
    print(f"{df['Transaction'][idx]:<12} {y_true:<6} {y_pred:<10.4f} {y_rounded:<8} {correct}")

# Calculate accuracy
correct_predictions = sum(1 for idx in range(len(X)) 
                         if (1 if np.dot(v, np.tanh(np.dot(W.T, X[idx]))) > 0.5 else 0) == y[idx])
accuracy = correct_predictions / len(X) * 100
print()
print(f"Training Accuracy: {accuracy:.1f}%")
# Out:
# ...
# FINAL PREDICTIONS
# ...
# Transaction  True   Predicted  Rounded  Correct?
# ------------------------------------------------------------
# T1           1      0.5154     1        ✓
# T2           0      0.0041     0        ✓
# T3           1      1.0093     1        ✓
# T4           0      0.0041     0        ✓
# T5           0      -0.0043    0        ✓
# T6           0      -0.0043    0        ✓
# T7           1      0.9940     1        ✓
# T8           0      0.5154     1        ✗
# T9           0      0.0074     0        ✓
# T10          1      0.9738     1        ✓
#
# Training Accuracy: 90.0%

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import warnings

warnings.filterwarnings('ignore', message='Glyph.*missing from font.*')

def network_output(x, W, v):
    """Compute network output for input x"""
    a = np.dot(W.T, x)
    h = np.tanh(a)
    return np.dot(v, h)

def create_decision_surface(W, v, resolution=25):
    """Create a mesh representing the decision boundary (output = 0.5)"""
    x_range = np.linspace(-0.2, 1.2, resolution)
    y_range = np.linspace(-0.2, 1.2, resolution)
    z_range = np.linspace(-0.2, 1.2, resolution)
    
    grid_output = np.zeros((resolution, resolution, resolution))
    
    for i, x_val in enumerate(x_range):
        for j, y_val in enumerate(y_range):
            for k, z_val in enumerate(z_range):
                x_test = np.array([x_val, y_val, z_val])
                grid_output[i, j, k] = network_output(x_test, W, v)
    
    return x_range, y_range, z_range, grid_output

def plot_network_decision_surface(ax, W, v, X, y, df, title):
    """Plot the decision boundary as a continuous surface"""
    
    # Create decision surface
    x_range, y_range, z_range, grid_output = create_decision_surface(W, v, resolution=25)
    
    print(f"Grid output range: [{grid_output.min():.3f}, {grid_output.max():.3f}]")
    
    surface_plotted = False
    
    # Try marching cubes if 0.5 is within the range
    if grid_output.min() < 0.5 < grid_output.max():
        try:
            from skimage import measure
            
            # Extract isosurface at output = 0.5
            verts, faces, _, _ = measure.marching_cubes(grid_output, level=0.5)
            
            # Scale vertices to actual coordinate range
            verts[:, 0] = verts[:, 0] / (len(x_range) - 1) * (x_range[-1] - x_range[0]) + x_range[0]
            verts[:, 1] = verts[:, 1] / (len(y_range) - 1) * (y_range[-1] - y_range[0]) + y_range[0]
            verts[:, 2] = verts[:, 2] / (len(z_range) - 1) * (z_range[-1] - z_range[0]) + z_range[0]
            
            # Plot the mesh
            ax.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2],
                           color='cyan', alpha=0.4, edgecolor='blue', linewidth=0.2)
            surface_plotted = True
            
        except ImportError:
            print("scikit-image not available")
    
    # Fallback: use slice method
    if not surface_plotted:
        print("Using slice visualization method...")
        n_slices = 10
        
        for z_val in np.linspace(0, 1, n_slices):
            X1, X2 = np.meshgrid(x_range, y_range)
            Z_out = np.zeros_like(X1)
            
            for i in range(X1.shape[0]):
                for j in range(X1.shape[1]):
                    x_test = np.array([X1[i, j], X2[i, j], z_val])
                    Z_out[i, j] = network_output(x_test, W, v)
            
            # Check if 0.5 is in range for this slice
            if Z_out.min() < 0.5 < Z_out.max():
                ax.contour(X1, X2, Z_out, levels=[0.5], 
                          colors='blue', linewidths=2, alpha=0.6, offset=z_val)
        
        # Also do Y slices
        for y_val in np.linspace(0, 1, n_slices):
            X1, X3 = np.meshgrid(x_range, z_range)
            Z_out = np.zeros_like(X1)
            
            for i in range(X1.shape[0]):
                for j in range(X1.shape[1]):
                    x_test = np.array([X1[i, j], y_val, X3[i, j]])
                    Z_out[i, j] = network_output(x_test, W, v)
            
            if Z_out.min() < 0.5 < Z_out.max():
                ax.contour(X1, Z_out, X3, levels=[0.5], 
                          colors='blue', linewidths=2, alpha=0.4, offset=y_val)
    
    # Plot data points
    for idx in range(len(X)):
        color = 'green' if y[idx] == 1 else 'red'
        ax.scatter(*X[idx], color=color, s=250, alpha=0.9, 
                  edgecolors='black', linewidth=2, zorder=10)
        ax.text(X[idx, 0], X[idx, 1], X[idx, 2] + 0.15, df['Transaction'][idx], 
                fontsize=9, ha='center', weight='bold')
    
    # Labels and formatting
    ax.set_xlabel('Music Download', fontsize=11, weight='bold')
    ax.set_ylabel('Music Streaming', fontsize=11, weight='bold')
    ax.set_zlabel('Online Games', fontsize=11, weight='bold')
    ax.set_title(title, fontsize=12, weight='bold', pad=10)
    
    ax.set_xlim([-0.3, 1.3])
    ax.set_ylim([-0.3, 1.3])
    ax.set_zlim([-0.3, 1.3])
    
    # Add legend
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='green', label='Buys (y=1)'),
        Patch(facecolor='red', label='Cancels (y=0)'),
        Patch(facecolor='cyan' if surface_plotted else 'blue', 
              alpha=0.4, label='Decision Boundary')
    ]
    ax.legend(handles=legend_elements, loc='upper left', fontsize=9)
    
    ax.view_init(elev=20, azim=45)

# Create visualization
fig = plt.figure(figsize=(18, 6))

# Initial state
W_init = history['W'][0]
v_init = history['v'][0]
ax1 = fig.add_subplot(131, projection='3d')
plot_network_decision_surface(ax1, W_init, v_init, X, y, df, 
                              f'Initial State (Iteration 0)\nRandom Weights')

# Mid-training
mid_iter = len(history['W']) // 2
W_mid = history['W'][mid_iter]
v_mid = history['v'][mid_iter]
ax2 = fig.add_subplot(132, projection='3d')
plot_network_decision_surface(ax2, W_mid, v_mid, X, y, df, 
                              f'Mid-Training (Iteration {mid_iter})\nLoss: {history["loss"][mid_iter]:.3f}')

# Final state
W_final = history['W'][-1]
v_final = history['v'][-1]
ax3 = fig.add_subplot(133, projection='3d')
plot_network_decision_surface(ax3, W_final, v_final, X, y, df, 
                              f'Final State (Iteration {MaxIter-1})\nLoss: {history["loss"][-1]:.3f}')

plt.tight_layout()
plt.show()

print("The decision boundary is non-linear")
# Out:
# Grid output range: [-0.010, 0.062]
# Using slice visualization method...
# Grid output range: [-0.241, 1.143]
# Grid output range: [-0.238, 1.246]
# ✓ Visualization complete!
# The decision boundary shows where the network is uncertain (output ≈ 0.5)
