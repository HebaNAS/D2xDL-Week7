# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: black;">Linear Regression</h1>
#         &nbsp;
#         <h3 style="text-align: center; font-size: 42px; line-height: 0px;">F20DL/F21DL</h3>
#         <h3 style="text-align: center; font-size: 42px;">Data Mining & Machine Learning</h3>
#         &nbsp;
#         <h3 style="text-align: center; font-size: 42px; line-height: 0px;">Dr. Heba El-Shimy</h3>
#         <h4 style="text-align: center; font-size: 36px; font-weight: 100;">Based on F20/21DL Slides on Canvas</h4>
#         <span>Code development was assisted by Claude.ai</span>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Linear Function</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 32px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#         <li style="margin-bottom: 30px;">
#             • A <span style="color: #3274B5;">linear function</span> of features \(\textit{x}_1, \textit{x}_2, \ldots, \textit{x}_D\) is a function that takes the form:
#             \[
#                 f_{\mathbf{w}}(x_1, x_2, \ldots, x_D) = w_0 + w_1x_1 + \ldots + w_Dx_D = \sum_{d=1}^{D} w_d x_d = \mathbf{w}^T \cdot \mathbf{x}
#             \]
#             where \(x_0 = 1\)
#         </li>
#     </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px;">Linear Regression</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row;">
#         <div style="width: 55%;">
#             <ul style="font-size: 28px; list-style: none; margin-top: 15px;">
#                 <li>
#                     • <it>“Linear regression is the problem of fitting a </it><span style="color: #3274B5;">linear function</span> <it>to a set of \(n\) examples, in which <span style="color: #3274B5;">usually<span> the input and output features are <span style="color: #3274B5;">numeric</span></it>”.
#                 </li>
#                 <li>
#                     • Aim: <span style="color: #A62B17;">Predict</span> the <span style="color: #3274B5;">output feature</span> \(\hat{Y}\) from input features \(\textit{x}_1, \textit{x}_2, \ldots, \textit{x}_D\)
#                 </li>
#                 <li>
#                     • Notation:
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ A <span style="color: #3274B5;">feature</span> is a <span style="color: #A62B17;">function</span> of an example \(\rightarrow\) often <span style="color: #3274B5;">human interpretation</span>
#                         </li>
#                         <li>
#                            ▸ The <span style="color: #3274B5;">Weights</span> denote the "<span style="color: #A62B17;">importance</span>" of features
#                         </li>
#                         <li>
#                            ▸ <span style="color: #3274B5;">sum of squared error (SSE)</span> on examples \(X\) for output features \(Y\) is:
#                             \[
#                                 SSE(\mathbf{X}, \mathbf{w}) = \sum_{\mathbf{x}_n \in X} (Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n))^2
#                             \]
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • Goal: Find <span style="color: #3274B5;">weights \(x\)</span> that <span style="color: #A62B17;">minimise \( SSE(X, w) \ldots \)</span>
#                 </li>
#                 <li>
#                     • Identical to optimising a <span style="color: #3274B5;">linear model</span> wrt the <span style="color: #3274B5;">squared objective function</span> \(l^{(sqr)}\) over \(n\) examples <span style="color: #3274B5;">without regularisation:</span>
#                     \[
#                         \min_{\mathbf{w}, b} \sum (y_n - (\mathbf{w}^T \cdot \mathbf{x}_n + b))^2, \text{ where } w_0 = b \text{ (bias term) and } x_0 = 1
#                     \]
#                 </li>
#                 <li>
#                     • The gradient becomes \(\nabla_{\mathbf{w}} = (y_n - \mathbf{w}^T \cdot \mathbf{x}_n)\mathbf{x}_n\)
#                 </li>
#             </ul>
#         </div>
#         <div style="width: 30%; margin-top: 1%; margin-left: 15%;">
#             <img src="images/linear-regression.png" alt="Linear Regression Plot" />
#         </div>
#     </div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">
#         &nbsp;
#     </div>
#     </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
X = np.array([1, 2, 3, 4, 5, 6])  # Hypothetical example: house sqft in 1,000s
y = np.array([6, 7, 10, 13, 13, 15])  # Hypothetical example: house price in 100,000s (target variable)

# Prepare data with bias term: x_n = [1, x]
X_with_bias = np.column_stack([np.ones(len(X)), X])

# Initialize weights: w = [w0, w1] (bias and slope)
w = np.array([0.0, 0.0])

# Hyperparameters
eta = 0.01  # learning rate η
max_iter = 50

# Store history
history = {}
steps_to_capture = [0, 5, 10, 20, 30, 49]
current_step = 0

# Training (for visualization only for now)
for k in range(max_iter):
    # Capture at the start of each epoch if needed
    if current_step in steps_to_capture:
        history[current_step] = (w[1], w[0])  # Store (slope, intercept)
    
    for i in range(len(X)):
        x_n = X_with_bias[i]  # [1, X[i]]
        Y_actual = y[i]
        
        # Compute predicted output
        Y_hat = np.dot(w, x_n)  # w^T · x_n
        
        # Compute scalar δ
        delta = Y_actual - Y_hat
        
        # Update weights
        w = w + eta * delta * x_n
    
    current_step += 1

if (max_iter - 1) in steps_to_capture and (max_iter - 1) not in history:
    history[max_iter - 1] = (w[1], w[0])

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()
steps_to_plot = [0, 5, 10, 20, 30, 49]

for idx, step in enumerate(steps_to_plot):
    if step in history:
        w_curr, b_curr = history[step]
        y_pred = w_curr * X + b_curr
        sse = np.sum((y - y_pred)**2)
        
        axes[idx].scatter(X, y, s=100, alpha=0.6)
        axes[idx].plot(X, y_pred, 'r-', linewidth=2)
        
        # Residuals
        for i in range(len(X)):
            axes[idx].plot([X[i], X[i]], [y[i], y_pred[i]], 
                          'gray', linestyle='--', alpha=0.5)
        
        axes[idx].set_title(f'Step {step}: SSE={sse:.2f}')
        axes[idx].grid(alpha=0.3)
    else:
        axes[idx].text(0.5, 0.5, f'Step {step}\nNot captured', 
                      ha='center', va='center', transform=axes[idx].transAxes)
        axes[idx].set_title(f'Step {step}: No data')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Linear Regression: Gradient Descent Algorithm</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#     \[
#         \begin{array}{l}
#         \hline
#         \color{purple}{\textbf{Algorithm: }} \text{LINEAR REGRESSION GRADIENT DESCENT}(\text{data}, maxIter, \eta) \\
#         \hline
#         \textbf{1: } \mathbf{w} \leftarrow \langle 0,0,\ldots,0 \rangle \text{ or randomly initialise} \quad \textit{// initialise weights} \\
#         \textbf{2: } \textbf{for } k = 1 \ldots maxIter \textbf{ do} \\
#         \textbf{3: } \quad \textbf{for all } (x, y) \in \text{data} \textbf{ do} \\
#         \textbf{4: } \qquad \hat{Y}(\mathbf{x}_n) = \mathbf{w}^T \cdot \mathbf{x}_n \quad \textit{// compute predicted output} \\
#         \textbf{5: } \qquad \delta = Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n) \quad \textit{// compute scalar } \delta \\
#         \textbf{6: } \qquad \mathbf{w} \leftarrow \mathbf{w} + \eta \cdot \delta \cdot \mathbf{x}_n \quad \textit{// update weights} \\
#         \textbf{7: } \quad \textbf{end for} \\
#         \textbf{8: } \textbf{end for} \\
#         \textbf{9: } \textbf{return } \mathbf{w} \\
#         \hline
#         \end{array}
#     \]
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Worked-out Example</h1>
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Customer Transactions</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Example: Customer Transactions</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#         <table style="border-collapse: collapse; font-size: 24px;">
#         <tr style="background: #ddd;">
#         <th>Transaction</th><th>Music DL?</th><th>Music Stream?</th><th>Online Games</th><th>Output</th>
#         </tr>
#         <tr><td>T1</td><td>No</td><td>Yes</td><td>Yes</td><td style="background: #ccc;">Buys</td></tr>
#         <tr><td>T2</td><td>Yes</td><td>No</td><td>No</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T3</td><td>Yes</td><td>No</td><td>Yes</td><td style="background: #ccc;">Buys</td></tr>
#         <tr><td>T4</td><td>Yes</td><td>No</td><td>No</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T5</td><td>No</td><td>Yes</td><td>No</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T6</td><td>No</td><td>Yes</td><td>No</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T7</td><td>No</td><td>No</td><td>Yes</td><td style="background: #ccc;">Buys</td></tr>
#         <tr><td>T8</td><td>No</td><td>Yes</td><td>Yes</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T9</td><td>Yes</td><td>Yes</td><td>No</td><td style="background: #ccc;">Cancels</td></tr>
#         <tr><td>T10</td><td>Yes</td><td>Yes</td><td>Yes</td><td style="background: #ccc;">Buys</td></tr>
#         </table>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">The classification option: Vectorise</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#         <table style="border-collapse: collapse; font-size: 24px;">
#         <tr style="background: #ddd;">
#         <th>Transaction</th><th>Music DL?</th><th>Music Stream?</th><th>Online Games</th><th>Output</th>
#         </tr>
#         <tr><td>T1</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T2</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T4</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T6</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T7</td><td>0</td><td>0</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T8</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T9</td><td>1</td><td>1</td><td>0</td><td style="background: #ccc;">-1</td></tr>
#         <tr><td>T10</td><td>1</td><td>1</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         </table>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0 80px 0 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">The classification option: Vectorise</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#         <table style="border-collapse: collapse;">
#         <tr style="background: #ddd;">
#         <th>Transaction</th><th>Music DL?</th><th>Music Stream?</th><th>Online Games</th><th>Output</th>
#         </tr>
#         <tr><td>T1</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T2</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T4</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T6</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T7</td><td>0</td><td>0</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T8</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T9</td><td>1</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">-1</td></tr>
#         <tr><td>T10</td><td>1</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         </table>
#     </div>
#     <ul style="font-size: 28px; list-style: none; margin-top: 15px;">
#                 <li>
#                     • Features:
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ Yes \(\rightarrow\) 1, No \(\rightarrow\) 0
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • Class (Output):
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ Buys \(\rightarrow\) 1, Cancels \(\rightarrow\) -1
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • <span style="color: #A62B17;">Minimise</span> any <span style="color: #3274B5;">objective function</span> \(l\), e.g. \(l^{(exp.)}\)
#                 </li>
#                 <li>
#                     • How to predict <span style="color: #A62B17;">class</span>?
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ \(\hat{y} = sign(\mathbf{w}^T \mathbf{x} + b)\), aka sign of the activation
#                         </li>
#                         <li>
#                            ▸ Similar to <span style="color: #3274B5;">Perceptron</span>
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • How to <span style="color: #A62B17;">evaluate</span>?
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ Measure Accuracy, Precision, Recall, F-1
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 10% 80px 10% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">The regression option: Turn to Numbers</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#         <table style="border-collapse: collapse; font-size: 24px;">
#         <tr style="background: #ddd;">
#         <th>Transaction</th><th>Music DL?</th><th>Music Stream?</th><th>Online Games</th><th>Output</th>
#         </tr>
#         <tr><td>T1</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T2</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T4</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T6</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T7</td><td>0</td><td>0</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         <tr><td>T8</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T9</td><td>1</td><td>1</td><td>0</td><td style="background: #ccc;">0</td></tr>
#         <tr><td>T10</td><td>1</td><td>1</td><td>1</td><td style="background: #ccc;">1</td></tr>
#         </table>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0 80px 0 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">The regression option: Turn to Numbers</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 20px;">
#         <table style="border-collapse: collapse;">
#         <tr style="background: #ddd;">
#         <th>Transaction</th><th>Music DL?</th><th>Music Stream?</th><th>Online Games</th><th>Output</th>
#         </tr>
#         <tr><td>T1</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T2</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T4</td><td>1</td><td>0</td><td>0</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T6</td><td>0</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T7</td><td>0</td><td>0</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         <tr><td>T8</td><td>0</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T9</td><td>1</td><td>1</td><td>0</td><td style="background: #ccc; text-align: center;">0</td></tr>
#         <tr><td>T10</td><td>1</td><td>1</td><td>1</td><td style="background: #ccc; text-align: center;">1</td></tr>
#         </table>
#     </div>
#     <ul style="font-size: 24px; list-style: none; margin-top: 15px;">
#                 <li>
#                     • Features:
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ Yes \(\rightarrow\) 1, No \(\rightarrow\) 0
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • We learn the function
#                     \[
#                         \begin{align}
#                         f(\text{musicDown, musicStream, onlineGames}) = \\
#                         w_o + w_1 \cdot \text{musicDown} + w_2 \cdot \text{musicStream} + w_4 \cdot \text{onlineGames}
#                         \end{align}
#                     \]
#                 </li>
#                 <li>
#                     • <span style="color: #A62B17;">Minimise</span> SSE, aka \(l^{(sqr)}\)
#                 </li>
#                 <li>
#                     • How to predict <span style="color: #A62B17;">output</span>?
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ Use directly the value of the <span style="color: #3274B5;">output</span>
#                             \[
#                                 \hat{Y}(\mathbf{x}_n) = \sum_{d=1}^{D} w_d x_d = \mathbf{w}^T \cdot \mathbf{x}
#                             \]
#                         </li>
#                         <li>
#                            ▸ Hopefully, the model will <span style="color: #A62B17;">learn to map</span> \(\hat{Y}(x_n)\) to something close to 0s and 1s
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • How to <span style="color: #A62B17;">evaluate</span>?
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li>
#                            ▸ SSE, or Mean Squared Error (MSE)
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import pandas as pd

# Data
data = pd.DataFrame({
    'Music DL?': [0, 1, 1, 1, 0, 0, 0, 0, 1, 1],
    'Music Stream?': [1, 0, 0, 0, 1, 1, 0, 1, 1, 1],
    'Online Games': [1, 0, 1, 0, 0, 0, 1, 1, 0, 1],
    'Output': [1, 0, 1, 0, 0, 0, 1, 0, 0, 1]
}, index=[f'T{i}' for i in range(1, 11)])

print("Training Data:")
display(data)

# Add bias term (the "1" at the beginning)
X = data.iloc[:, :-1].values
X_with_bias = np.column_stack([np.ones(len(X)), X])  # Add column of 1s
y = data['Output'].values

print("\nX with bias term (w_0)):")
print(X_with_bias[:2])
print(f"\nT1: x = {X_with_bias[0]}, y = {y[0]}")
print(f"T2: x = {X_with_bias[1]}, y = {y[1]}")
# Out:
# Training Data:
#      Music DL?  Music Stream?  Online Games  Output
# T1           0              1             1       1
# T2           1              0             0       0
# T3           1              0             1       1
# T4           1              0             0       0
# T5           0              1             0       0
# T6           0              1             0       0
# T7           0              0             1       1
# T8           0              1             1       0
# T9           1              1             0       0
# T10          1              1             1       1
# X with bias term (w_0)):
# [[1. 0. 1. 1.]
#  [1. 1. 0. 0.]]
#
# T1: x = [1. 0. 1. 1.], y = 1
# T2: x = [1. 1. 0. 0.], y = 0

# %%
# Walkthrough of first iteration
print("=" * 60)
print("Let's train on first 2 examples")
print("=" * 60)

# Initialize weights randomly
w = np.array([1, 2, 3, 1])  # [w0, w1, w2, w3]
eta = 1  # learning rate

print(f"\nInitial weights: w = {w}")
print(f"Learning rate: η = {eta}")

# Iteration 1, Example T1
print("\n" + "="*60)
print("ITERATION 1 - Example T1")
print("="*60)
x_T1 = X_with_bias[0]  # [1, 0, 1, 1]
y_T1 = y[0]  # 1

print(f"\nx_T1 = {x_T1}")
print(f"y_T1 = {y_T1}")

# Line 4 of the gradient decsent algorithm: Compute prediction
y_hat = np.dot(w, x_T1)
print(f"\nŷ(x_T1) = w^T · x_T1")
print(f"        = {w} · {x_T1}")
print(f"        = {w[0]}*{x_T1[0]} + {w[1]}*{x_T1[1]} + {w[2]}*{x_T1[2]} + {w[3]}*{x_T1[3]}")
print(f"        = {y_hat}")

# Line 5 of the gradient decsent algorithm: Compute error
delta = y_T1 - y_hat
print(f"\nδ = Y(x_T1) - ŷ(x_T1)")
print(f"  = {y_T1} - {y_hat}")
print(f"  = {delta}")

# Line 6 of the gradient decsent algorithm: Update weights
w_old = w.copy()
w = w + eta * delta * x_T1
print(f"\nw^(1) = w^(0) + η · δ · x_T1")  # from slide 3 
print(f"      = {w_old} + {eta} * {delta} * {x_T1}")
print(f"      = {w_old} + {eta * delta * x_T1}")
print(f"      = {w}")
# Out:
# ...
# Let's train on first 2 examples
# ...
#
# Initial weights: w = [1 2 3 1]
# Learning rate: η = 1
#
# ...
# ITERATION 1 - Example T1
# ...
#
# x_T1 = [1. 0. 1. 1.]
# y_T1 = 1
#
# ŷ(x_T1) = w^T · x_T1
#         = [1 2 3 1] · [1. 0. 1. 1.]
#         = 1*1.0 + 2*0.0 + 3*1.0 + 1*1.0
#         = 5.0
#
# δ = Y(x_T1) - ŷ(x_T1)
#   = 1 - 5.0
#   = -4.0
#
# w^(1) = w^(0) + η · δ · x_T1
#       = [1 2 3 1] + 1 * -4.0 * [1. 0. 1. 1.]
#       = [1 2 3 1] + [-4. -0. -4. -4.]
#       = [-3.  2. -1. -3.]

# %%
# Iteration 1, Example T2
print("\n" + "="*60)
print("ITERATION 1 - Example T2")
print("="*60)
x_T2 = X_with_bias[1] # [1, 0, 0]
y_T2 = y[1]  # 0

print(f"\nx_T2 = {x_T2}")
print(f"y_T2 = {y_T2}")

# Line 4 of the gradient decsent algorithm: Compute prediction
y_hat = np.dot(w, x_T2)
print(f"\nŷ(x_T2) = w^T · x_T2")
print(f"        = {w} · {x_T2}")
print(f"        = {w[0]}*{x_T2[0]} + {w[1]}*{x_T2[1]} + {w[2]}*{x_T2[2]} + {w[3]}*{x_T2[3]}")
print(f"        = {y_hat}")

# Line 5 of the gradient decsent algorithm: Compute error
delta = y_T2 - y_hat
print(f"\nδ = Y(x_T2) - ŷ(x_T2)")
print(f"  = {y_T2} - {y_hat}")
print(f"  = {delta}")

# Line 6 of the gradient decsent algorithm: Update weights
w_old = w.copy()
w = w + eta * delta * x_T2
print(f"\nw^(1) = w^(0) + η · δ · x_T2")
print(f"      = {w_old} + {eta} * {delta} * {x_T2}")
print(f"      = {w_old} + {eta * delta * x_T2}")
print(f"      = {w}")
# Out:
# ...
# ITERATION 1 - Example T2
# ...
#
# x_T2 = [1. 1. 0. 0.]
# y_T2 = 0
#
# ŷ(x_T2) = w^T · x_T2
#         = [-3.  2. -1. -3.] · [1. 1. 0. 0.]
#         = -3.0*1.0 + 2.0*1.0 + -1.0*0.0 + -3.0*0.0
#         = -1.0
#
# δ = Y(x_T2) - ŷ(x_T2)
#   = 0 - -1.0
#   = 1.0
#
# w^(1) = w^(0) + η · δ · x_T2
#       = [-3.  2. -1. -3.] + 1 * 1.0 * [1. 1. 0. 0.]
#       = [-3.  2. -1. -3.] + [1. 1. 0. 0.]
#       = [-2.  3. -1. -3.]

# %%
# After iteration 1, let's make predictions with the updated weights
print("\n" + "="*60)
print("MAKING PREDICTIONS AFTER ITERATION 1")
print("="*60)

print(f"\nWeights after iteration 1: w = {w}")
print(f"\nLet's predict on the first 2 examples (outside the training loop)")

# Predict on T1
print("\n" + "-"*60)
print("Prediction for T1:")
print("-"*60)
x_T1 = X_with_bias[0]  # [1, 0, 1, 1]
y_T1 = y[0]  # 1

y_hat_T1 = np.dot(w, x_T1)
print(f"\nŷ(x_T1) = w^T · x_T1")
print(f"        = {w} · {x_T1}")
print(f"        = {w[0]:.1f}*{x_T1[0]} + {w[1]:.1f}*{x_T1[1]} + {w[2]:.1f}*{x_T1[2]} + {w[3]:.1f}*{x_T1[3]}")
print(f"        = {y_hat_T1:.1f}")
print(f"\nActual: y_T1 = {y_T1}")
print(f"Error: {y_T1} - {y_hat_T1:.1f} = {y_T1 - y_hat_T1:.1f}")

# Predict on T2
print("\n" + "-"*60)
print("Prediction for T2:")
print("-"*60)
x_T2 = X_with_bias[1]  # [1, 1, 0, 0]
y_T2 = y[1]  # 0

y_hat_T2 = np.dot(w, x_T2)
print(f"\nŷ(x_T2) = w^T · x_T2")
print(f"        = {w} · {x_T2}")
print(f"        = {w[0]:.1f}*{x_T2[0]} + {w[1]:.1f}*{x_T2[1]} + {w[2]:.1f}*{x_T2[2]} + {w[3]:.1f}*{x_T2[3]}")
print(f"        = {y_hat_T2:.1f}")
print(f"\nActual: y_T2 = {y_T2}")
print(f"Error: {y_T2} - {y_hat_T2:.1f} = {y_T2 - y_hat_T2:.1f}")

# Calculate SSE for these two examples
print("\n" + "="*60)
print("CALCULATING ERROR (SSE)")
print("="*60)
sse = (y_T1 - y_hat_T1)**2 + (y_T2 - y_hat_T2)**2
print(f"\nSSE(X, w) = Σ (Y(x_n) - ŷ(x_n))²")
print(f"          = (Y(x_T1) - ŷ(x_T1))² + (Y(x_T2) - ŷ(x_T2))²")
print(f"          = ({y_T1} - ({y_hat_T1:.1f}))² + ({y_T2} - ({y_hat_T2:.1f}))²")
print(f"          = ({y_T1 - y_hat_T1:.1f})² + ({y_T2 - y_hat_T2:.1f})²")
print(f"          = {(y_T1 - y_hat_T1)**2:.1f} + {(y_T2 - y_hat_T2)**2:.1f}")
print(f"          = {sse:.1f}")

print("\n" + "="*60)
print("Obviously, the predictions are way off... why?")
print("Because we've only done ONE iteration of training!")
print("The model needs more iterations to learn the patterns.")
print("="*60)
# Out:
# ...
# MAKING PREDICTIONS AFTER ITERATION 1
# ...
#
# Weights after iteration 1: w = [-2.  3. -1. -3.]
#
# Let's predict on the first 2 examples (outside the training loop)
#
# ------------------------------------------------------------
# Prediction for T1:
# ------------------------------------------------------------
#
# ŷ(x_T1) = w^T · x_T1
#         = [-2.  3. -1. -3.] · [1. 0. 1. 1.]
#         = -2.0*1.0 + 3.0*0.0 + -1.0*1.0 + -3.0*1.0
#         = -6.0
#
# Actual: y_T1 = 1
# Error: 1 - -6.0 = 7.0
#
# ------------------------------------------------------------
# Prediction for T2:
# ------------------------------------------------------------
#
# ŷ(x_T2) = w^T · x_T2
#         = [-2.  3. -1. -3.] · [1. 1. 0. 0.]
#         = -2.0*1.0 + 3.0*1.0 + -1.0*0.0 + -3.0*0.0
#         = 1.0
#
# Actual: y_T2 = 0
# Error: 0 - 1.0 = -1.0
#
# ...
# CALCULATING ERROR (SSE)
# ...
#
# SSE(X, w) = Σ (Y(x_n) - ŷ(x_n))²
#           = (Y(x_T1) - ŷ(x_T1))² + (Y(x_T2) - ŷ(x_T2))²
#           = (1 - (-6.0))² + (0 - (1.0))²
# ...

# %%
# Full training process with visualization
def train_with_history(X, y, eta=0.3, max_iter=10):
    """Train and record history for visualization"""
    n_samples, n_features = X.shape
    w = np.array([1, 2, 3, 1], dtype=float)  # Initialize
    
    history = {
        'weights': [w.copy()],
        'predictions': [],
        'errors': [],
        'iteration': [0],
        'example': ['Initial']
    }
    
    for iteration in range(1, max_iter + 1):
        for i in range(n_samples):
            # Prediction
            y_hat = np.dot(w, X[i])
            
            # Error
            delta = y[i] - y_hat
            
            # Update
            w = w + eta * delta * X[i]
            
            # Record
            history['weights'].append(w.copy())
            history['predictions'].append(y_hat)
            history['errors'].append(delta)
            history['iteration'].append(iteration)
            history['example'].append(f'T{i+1}')
    
    return w, history

# Train
final_w, history = train_with_history(X_with_bias, y, eta=0.3, max_iter=5)

print(f"Final weights after 5 iterations: {final_w}")
# Out:
# Final weights after 5 iterations: [-0.9279378   0.81205452  0.25190176  0.89226799]

# %%
# Visualize weight evolution
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

weight_names = ['w₀ (bias)', 'w₁ (Music DL)', 'w₂ (Music Stream)', 'w₃ (Online Games)']

for i, (ax, name) in enumerate(zip(axes, weight_names)):
    weights_i = [w[i] for w in history['weights']]
    ax.plot(weights_i, 'o-', linewidth=2, markersize=6)
    ax.axhline(y=final_w[i], color='r', linestyle='--', alpha=0.5, label='Final value')
    ax.set_xlabel('Update step', fontsize=12)
    ax.set_ylabel(name, fontsize=12)
    ax.set_title(f'Evolution of {name}', fontsize=13)
    ax.grid(alpha=0.3)
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Loss over time
fig, ax1 = plt.subplots(1, 1, figsize=(14, 5))

# Calculate SSE (Sum of Squared Errors) over iterations
losses = []
for step in range(0, len(history['weights']), len(X_with_bias)):
    w_step = history['weights'][step]
    y_pred = np.dot(X_with_bias, w_step)  # Raw predictions
    sse = np.sum((y - y_pred) ** 2)  # Sum of squared errors
    losses.append(sse)

ax1.plot(range(len(losses)), losses, 'o-', linewidth=2, markersize=8, color='red')
ax1.set_xlabel('Iteration', fontsize=12)
ax1.set_ylabel('SSE (Sum of Squared Errors)', fontsize=12)
ax1.set_title('Training Loss over Iterations', fontsize=13)
ax1.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# Final predictions
y_pred_final = np.sign(np.dot(X_with_bias, final_w))
y_pred_final[y_pred_final == 0] = 1

comparison = pd.DataFrame({
    'True Output': y,
    'Predicted': y_pred_final.astype(int),
    'Correct': y == y_pred_final
}, index=[f'T{i}' for i in range(1, 11)])

print("\nFinal Comparison:")
print(comparison)
print(f"\nFinal Accuracy: {np.mean(y == y_pred_final):.1%}")
print(f"Final SSE: {losses[-1]:.2f}")
# Out:
# Final Comparison:
#      True Output  Predicted  Correct
# T1             1          1     True
# T2             0         -1    False
# T3             1          1     True
# T4             0         -1    False
# T5             0         -1    False
# T6             0         -1    False
# T7             1         -1    False
# T8             0          1    False
# T9             0          1    False
# T10            1          1     True
#
# Final Accuracy: 30.0%
# Final SSE: 2.74

# %%
# Train the model properly with more iterations and smaller learning rate
print("="*60)
print("TRAINING WITH MORE ITERATIONS AND SMALLER LEARNING RATE")
print("="*60)

# Reset and train properly
w_final, history_final = train_with_history(X_with_bias, y, eta=0.01, max_iter=100)

print(f"\nFinal weights after 100 iterations (η=0.01):")
print(f"w₀ (bias)        = {w_final[0]:.3f}")
print(f"w₁ (Music DL)    = {w_final[1]:.3f}")
print(f"w₂ (Music Stream) = {w_final[2]:.3f}")
print(f"w₃ (Online Games) = {w_final[3]:.3f}")

print("\n" + "="*60)
print("INTERPRETING THE WEIGHTS")
print("="*60)

print(f"\nBuys = f(musicDown, musicStream, onlineGames)")
print(f"     = {w_final[0]:.3f}")
print(f"       + {w_final[1]:.3f} * musicDown")
print(f"       + {w_final[2]:.3f} * musicStream")
print(f"       + {w_final[3]:.3f} * onlineGames")

# Make predictions
y_pred_final = np.dot(X_with_bias, w_final)
errors = y - y_pred_final

# Create results table with color coding
results_df = pd.DataFrame({
    'Transaction': [f'T{i}' for i in range(1, 11)],
    'Actual': y,
    'Predicted': y_pred_final.round(3),
    'Error': errors.round(3)
})

# Visualize the results table with color coding
fig, ax = plt.subplots(figsize=(10, 8))
ax.axis('tight')
ax.axis('off')

# Create color map for cells
cell_colors = []
for _, row in results_df.iterrows():
    row_colors = ['lightgray', 'lightgray']  # Transaction, Actual
    
    # Color predicted values
    if 0.4 <= row['Predicted'] <= 0.6:
        row_colors.append('#90EE90')  # Light green for good predictions
    else:
        row_colors.append('#90EE90')  # Light green
    
    # Color errors
    abs_error = abs(row['Error'])
    if abs_error < 0.1:
        row_colors.append('#90EE90')  # Green for small errors
    elif abs_error < 0.3:
        row_colors.append('#FFB6C1')  # Light red for medium errors
    else:
        row_colors.append('#FF9999')  # Red for large errors
    
    cell_colors.append(row_colors)

table = ax.table(cellText=results_df.values, colLabels=results_df.columns,
                cellLoc='center', loc='center', cellColours=cell_colors,
                colWidths=[0.2, 0.2, 0.25, 0.25])

table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 2.5)

# Style header
for i in range(len(results_df.columns)):
    table[(0, i)].set_facecolor('#666666')
    table[(0, i)].set_text_props(weight='bold', color='white')

plt.title('Predictions After Training\n(Green=Good, Red=Poor)', 
          fontsize=14, weight='bold', pad=20)
plt.show()
# Out:
# ...
# TRAINING WITH MORE ITERATIONS AND SMALLER LEARNING RATE
# ...
#
# Final weights after 100 iterations (η=0.01):
# w₀ (bias)        = -0.574
# w₁ (Music DL)    = 0.522
# w₂ (Music Stream) = 0.337
# w₃ (Online Games) = 0.922
#
# ...
# INTERPRETING THE WEIGHTS
# ...
#
# Buys = f(musicDown, musicStream, onlineGames)
#      = -0.574
#        + 0.522 * musicDown
#        + 0.337 * musicStream
#        + 0.922 * onlineGames

# %%
# Show why these predictions aren't ideal for classification
print("\n" + "="*60)
print("WHY CONTINUOUS PREDICTIONS AREN'T IDEAL FOR CLASSIFICATION")
print("="*60)

# Apply threshold at 0.5 for classification
y_pred_class = (y_pred_final >= 0.5).astype(int)
accuracy = np.mean(y_pred_class == y)

comparison_class = pd.DataFrame({
    'Transaction': [f'T{i}' for i in range(1, 11)],
    'Actual': y,
    'Predicted Value': y_pred_final.round(3),
    'Predicted Class': y_pred_class,
    'Correct?': y_pred_class == y
})

print(comparison_class.to_string(index=False))
print(f"\nClassification Accuracy: {accuracy:.1%}")

print("\n" + "="*60)
print("PROBLEM: Predictions are actual numbers, not probabilities!")
print("• Values can be < 0 or > 1")
print("• Hard to interpret as 'probability of buying'")
print("• Better approach: Use logistic regression or perceptron")
print("="*60)
# Out:
# ...
# WHY CONTINUOUS PREDICTIONS AREN'T IDEAL FOR CLASSIFICATION
# ...
# Transaction  Actual  Predicted Value  Predicted Class  Correct?
#          T1       1            0.685                1      True
#          T2       0           -0.051                0      True
#          T3       1            0.871                1      True
#          T4       0           -0.051                0      True
#          T5       0           -0.237                0      True
#          T6       0           -0.237                0      True
#          T7       1            0.348                0     False
#          T8       0            0.685                1     False
#          T9       0            0.286                0      True
#         T10       1            1.208                1      True
#
# Classification Accuracy: 80.0%
#
# ...
# PROBLEM: Predictions are actual numbers, not probabilities!
# • Values can be < 0 or > 1
# • Hard to interpret as 'probability of buying'
# ...

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Linear Regression: Closed Form Solution</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 20px; list-style: none; margin-top: 15px;">
#                 <li style="margin-top: 20px;">
#                     • Recall our optimisation problem has become: \(L(w) = \textit{min}_w \sum_n (y_n - (w^T \cdot x_n))^2\)
#                 </li>
#                 <li style="margin-top: 20px;">
#                     • Converting to matrix form \(w^T \cdot x_n = x_{n}^{T} \cdot w = X \cdot w\), and \(L(w)\) becomes \((Y - X \cdot w)^T (Y - X \cdot w)\), where
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ \(Y\) is the vector of all outputs \((N \times 1)\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(X\) is the matrix of all inputs \((N \times D)\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(w\) is the weight vector \((D \times 1)\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \((Y - X \cdot w)^T (Y - X \cdot w)\) is the dot product of the error vector by itself (to get the sum of squared errors)
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-top: 20px;">
#                     • Expanding \(L(w) = (Y - X \cdot w)^T (Y - X \cdot w)\)
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ \(= Y^T Y - Y^T(Xw) - (Xw)^T Y + (Xw)^T(Xw)\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(= Y^T Y - Y^T Xw - (Xw)^T Y + (Xw)^T Xw\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(= Y^T Y - Y^T Xw - w^T X^T Y + w^T X^T Xw\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(= Y^T Y - 2w^T X^T Y + w^T X^T Xw\)
#                             <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                                 <li style="margin-top: 15px;">
#                                     - as \(Y^T Xw = (Y^T Xw)^T = w^T X^T Y\); meaning that \(Y^T Xw\) and \(w^T X^T Y\) are the same
#                                 </li>
#                             </ul>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Linear Regression: Closed Form Solution</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 20px; list-style: none; margin-top: 15px;">
#                 <li style="margin-top: 20px;">
#                     • Deriving \(L(w) = Y^T Y - 2w^T X^T Y + w^T X^T Xw\)
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ \(\frac{\partial}{\partial{w}}(Y^T \cdot Y) = 0\);
#                             <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                                 <li style="margin-top: 15px;">
#                                     - because \((Y^T \cdot Y)\) is a constant
#                                 </li>
#                             </ul>
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(\frac{\partial}{\partial{w}} (-2w^T X^T Y) = -2(X^T Y)\);
#                             <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                                 <li style="margin-top: 15px;">
#                                     - as \(\frac{\partial}{\partial{w}} (w^T a) = a\) where \(a\) is a constant and \(a = X^T Y\) here
#                                 </li>
#                             </ul>
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(\frac{\partial}{\partial{w}} (w^T X^T X w) = 2(X^T X)w\);
#                             <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                                 <li style="margin-top: 15px;">
#                                     - as \(\frac{\partial}{\partial{w}} (w^T W w) = 2Aw\) if \(A\) is symmetric and \(A = X^T X\) here
#                                 </li>
#                             </ul>
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ Therefore: \(\Delta_w L(w) = 0 - 2X^T Y + 2X^T Xw\) </br>
#                             \(\Delta_w L(w) = 2X^T Xw - 2X^T Y\)
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-top: 20px;">
#                     • By <span style="color: #A62B17;">setting the derivative of \(\Delta_w L(W) = 0\)</span> we can arrive at:
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ \(2X^T Xw - 2X^T Y = 0\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(X^T Xw - X^T Y = 0\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(X^T Xw = X^T Y\)
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(w = \frac{(X^T Y)}{(X^T X)}\)
#                         </li>
#                         <li>
#                            ▸ <span style="color: #3274B5;">\(w = (X^TX)^{-1}X^TY\)</span> where \(X\) is the dataset \((N \times D)\), \(Y\) are all the gold output values \((N \times 1)\)
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Linear Regression: Closed Form Solution</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <ul style="font-size: 20px; list-style: none; margin-top: 15px;">
#                 <li style="margin-top: 20px;">
#                     • Why not do this then?
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ <span style="color: #A62B17;">Complexity</span> of <span style="color: #3274B5;">Gradient Descent</span> is <span style="color: #3274B5;">\(\mathcal{O}(KND)\)</span>, where \(K\) are the number of iterations
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ <span style="color: #A62B17;">Complexity</span> of <span style="color: #3274B5;">Closed Form Solution</span> is <span style="color: #3274B5;">\(\mathcal{O}(D^3 + D^2N)\)</span>
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(\frac{\partial}{\partial{w}} (w^T X^T X w) = 2(X^T X)w\);
#                             <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                                 <li style="margin-top: 15px;">
#                                     - Most of the times \(N > D\), hence complexity is dominated by <span style="color: #3274B5;">\(\mathcal{O}(D^2N)\)</span>
#                                 </li>
#                             </ul>
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • Do we need to run more than \(D\)-many iterations \(K\)???
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ If we can get good results with \(K \lt D\) (or even \(K \lt\lt D)\), then gradient descent can be very efficient, especially for high-dimensional problems where \(D^3\) is prohibitively expensive.
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ In practice, we often don't need \(K \lt\lt D\), which is one reason gradient descent is widely used in machine learning
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     • Rule of thumb:
#                     <ul style="list-style: none; margin-left: 20px; margin-top: 15px;">
#                         <li style="margin-top: 15px;">
#                            ▸ \(D \le 100 \rightarrow\) closed-form is faster
#                         </li>
#                         <li style="margin-top: 15px;">
#                            ▸ \(D \ge 10,000 \rightarrow\) probably gradient descent is faster
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %%
import time

# Demonstrate both methods on small data
print("="*70)
print("EXAMPLE: Comparing Both Methods")
print("="*70)

# Use our existing data
X_demo = X_with_bias
y_demo = y
N, D = X_demo.shape

print(f"\nDataset: N={N} examples, D={D} features (including bias)")

# Method 1: Gradient Descent (we already did this)
start_time = time.time()
w_gd, _ = train_with_history(X_demo, y_demo, eta=0.01, max_iter=100)
time_gd = time.time() - start_time

# Method 2: Closed Form Solution
start_time = time.time()
w_closed = np.linalg.inv(X_demo.T @ X_demo) @ X_demo.T @ y_demo
time_closed = time.time() - start_time

print(f"\n{'Method':<20} {'Time (ms)':<15} {'Weights'}")
print("-"*70)
print(f"{'Gradient Descent':<20} {time_gd*1000:>10.4f} ms   {w_gd}")
print(f"{'Closed Form':<20} {time_closed*1000:>10.4f} ms   {w_closed}")

# Compare predictions
y_pred_gd = X_demo @ w_gd
y_pred_closed = X_demo @ w_closed
sse_gd = np.sum((y_demo - y_pred_gd)**2)
sse_closed = np.sum((y_demo - y_pred_closed)**2)

print(f"\n{'Method':<20} {'SSE (Error)':<15}")
print("-"*70)
print(f"{'Gradient Descent':<20} {sse_gd:>10.4f}")
print(f"{'Closed Form':<20} {sse_closed:>10.4f}")
print(f"\n→ Closed form gives the EXACT optimal solution!")
print(f"→ Gradient descent approximates it (depends on iterations)")
# Out:
# ...
# EXAMPLE: Comparing Both Methods
# ...
#
# Dataset: N=10 examples, D=4 features (including bias)
#
# Method               Time (ms)       Weights
# ----------------------------------------------------------------------
# Gradient Descent         3.1917 ms   [-0.57376264  0.52246319  0.33721903  0.92197989]
# Closed Form              0.0448 ms   [ 4.44089210e-16  1.17647059e-01 -1.17647059e-01  8.23529412e-01]
#
# Method               SSE (Error)
# ----------------------------------------------------------------------
# Gradient Descent         1.2525
# Closed Form              0.7059
#
# → Closed form gives the EXACT optimal solution!
# → Gradient descent approximates it (depends on iterations)

# %%
# Visualize the complexity comparison
print("\n" + "="*70)
print("COMPUTATIONAL COMPLEXITY: When to use which method?")
print("="*70)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Scenario 1: Varying number of features (D), fixed N=1000
N_fixed = 1000
D_range = np.arange(10, 500, 10)
K = 100  # iterations for GD

time_gd_D = K * N_fixed * D_range  # O(K*N*D)
time_closed_D = D_range**3 + D_range**2 * N_fixed  # O(D³ + D²N)

ax1.plot(D_range, time_gd_D / 1e6, label=f'Gradient Descent (K={K} iterations)', 
         linewidth=2, color='blue')
ax1.plot(D_range, time_closed_D / 1e6, label='Closed Form', 
         linewidth=2, color='red')
ax1.axvline(x=100, color='green', linestyle='--', alpha=0.7, linewidth=2)
ax1.text(105, max(time_closed_D / 1e6) * 0.8, 'D=100\nRule of thumb', 
         fontsize=11, color='green', weight='bold')
ax1.set_xlabel('Number of Features (D)', fontsize=13)
ax1.set_ylabel('Relative Computation (millions of ops)', fontsize=13)
ax1.set_title(f'Fixed N={N_fixed} samples', fontsize=14, weight='bold')
ax1.legend(fontsize=11)
ax1.grid(alpha=0.3)

# Scenario 2: Varying number of samples (N), fixed D=50
D_fixed = 50
N_range = np.arange(100, 20000, 500)

time_gd_N = K * N_range * D_fixed  # O(K*N*D)
time_closed_N = D_fixed**3 + D_fixed**2 * N_range  # O(D³ + D²N)

ax2.plot(N_range, time_gd_N / 1e6, label=f'Gradient Descent (K={K} iterations)', 
         linewidth=2, color='blue')
ax2.plot(N_range, time_closed_N / 1e6, label='Closed Form', 
         linewidth=2, color='red')
ax2.axvline(x=10000, color='green', linestyle='--', alpha=0.7, linewidth=2)
ax2.text(10500, max(time_gd_N / 1e6) * 0.7, 'N=10,000\nRule of thumb', 
         fontsize=11, color='green', weight='bold')
ax2.set_xlabel('Number of Samples (N)', fontsize=13)
ax2.set_ylabel('Relative Computation (millions of ops)', fontsize=13)
ax2.set_title(f'Fixed D={D_fixed} features', fontsize=14, weight='bold')
ax2.legend(fontsize=11)
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ...
# COMPUTATIONAL COMPLEXITY: When to use which method?
# ...

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Logistic Regression</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 1% 50px 1% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Recall: Binary Classification via Hyperplanes</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row; justify-content: center;">
#         <div style="width: 50%; margin-right: 8%;">
#             <ul style="font-size: 28px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#                 <li style="margin-bottom: 20px;">
#                     • A <span style="color: #3274B5;">Linear Classifier</span> is a hyperplane \((w, b)\)
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 15px;">
#                             ▸ At test time, we check on what side of the hyperplane examples fall
#                             \[
#                                 \hat{y} = \mathit{sign} (w^T \cdot x + b)
#                             \]
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     • A <span style="color: #3274B5;">Linear Regression</span>
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 15px;">
#                             ▸ At test time, we use directly the value of the <span style="color: #3274B5;">output</span>
#                             \[
#                                 \hat{Y}(x) = w^T \cdot x
#                             \]
#                         </li>
#                         <li style="margin-bottom: 15px;">
#                             ▸ …and learn to “<span style="color: #A62B17;">map</span>" to the <span style="color: #3274B5;">pre-defined values</span> for gold <span style="color: #3274B5;">classes</span> of our dataset, for example:
#                             \[
#                                 1 \rightarrow \mathit{true}
#                             \]
#                             \[
#                                 0 \rightarrow \mathit{false}
#                             \]
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#         <div style="width: 40%; margin-top: 1%;">
#             <img src="images/hyperplane3.png" alt="Hyperplane in 2D space" />
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 1% 50px 1% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Sigmoid (logistic) activation function</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row; justify-content: center;">
#         <div style="width: 50%; margin-right: 8%;">
#             <ul style="font-size: 28px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#                 <li style="margin-bottom: 20px;">
#                     • What if…we wanted to <span style="color: #A62B17;">estimate the probability of
# the class \(P(\hat{Y}(x)|x)\)</span> <span style="color: #3274B5;">directly from the input features \(x_n\)</span> with a linear model?
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 15px;">
#                             ▸ \(
#                                 P(\hat{Y}(x)|x) = w^T \cdot x
#                             \) wouldn’t work as the output is not necessarily bound to \({0, 1}\)
#                         </li>
#                     </ul>
#                 </li>
#                 <li style="margin-bottom: 20px;">
#                     • We can use the sigmoid (or logistic) function:
#                     <ul style="list-style: none; margin-left: 40px; margin-top: 15px;">
#                         <li style="margin-bottom: 15px;">
#                             ▸ \( \sigma(x) = \frac{1}{1 + e^{-x}}\)
#                         </li>
#                         <li style="margin-bottom: 15px;">
#                             ▸ so that
#                             \[
#                                 P(\hat{Y}(x)|x) = \frac{1}{1 + e^{-w^T \cdot x}}
#                             \]
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#         <div style="width: 40%; margin-top: 1%;">
#             <img src="images/sigmoid.png" alt="Hyperplane in 2D space" />
#         </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 1% 50px 1% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Use Case: Gradient Calculation for \(l^{(sqr)}\)</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row; justify-content: center;">
#         <ul style="font-size: 28px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#             <li style="margin-bottom: 20px;">
#                 • Consider the following <span style="color: #3274B5;">learning objective</span>
#                 \[
#                     L(\mathbf{w}) = \sum_{n} \left( Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n) \right)^2, \text{ where } \hat{Y}(\mathbf{x}_n) = \sigma(\mathbf{w}^T \cdot \mathbf{x}_n)
#                 \]
#             </li>
#             <li style="margin-bottom: 20px;">
#                 • What do we need in order to run <span style="color: #3274B5;">gradient descent</span>?
#             </li>
#         </ul>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 50px 0% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">\(l^{(sqr)}\): Derivative with respect to w</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="text-align: left; margin-left: 0; font-size: 18px;">
#                 \[
# \nabla_{\mathbf{w}} L = \nabla_{\mathbf{w}} \sum_{n} \left( Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n) \right)^2
# \]
#                 \[
#                     = \nabla_{\mathbf{w}} \sum_{n} \left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right)^2
#                 \]
#                 // power rule (brings down the 2) + chain rule (multiply by derivative of inside)
#                 \[
# = \sum_{n} 2\left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) \nabla_{\mathbf{w}} \left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right)
#                 \]
#                 // sum rule: the derivative of a difference is the difference of derivatives
#                 \[
# = \sum_{n} 2\left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) -\nabla_{\mathbf{w}} \sigma(\mathbf{w}^T \cdot \mathbf{x}_n)
#                 \]
#                 // chain Rule: the derivative of the sigmoid function is sigma times one minus sigma.
#                 \[
# = \sum_{n} -2\left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \left( 1 - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) \nabla_{\mathbf{w}} \mathbf{w}^T \cdot \mathbf{x}_n
#                 \]
#                 // constant rule: the derivative of the dot product w^T·x with respect to w is x
#                 \[
# = \sum_{n} -2\left( Y(\mathbf{x}_n) - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \left( 1 - \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \right) \mathbf{x}_n
#                 \]
#                 // since Y^(x_n)=σ(w^T⋅x_n)
#                 \[
#                     \sum_n -2(Y(x_n) - \hat{Y}(x_n)) \hat{Y}(x_n) (1 - \hat{Y}(x_n)) x_n
#                 \]
#                 // let the error (delta) =Y(x_n)−Y^(x)n)
#                 \[
# = \sum_{n} -2 \delta \hat{Y}(\mathbf{x}_n) \left( 1 - \hat{Y}(\mathbf{x}_n) \right) \cdot x_n, \quad \text{where } \delta = Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n)
#                 \]
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 80px 0% 80px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">Logistic Regression: Gradient Descent Algorithm</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="width: 70%; font-size: 18px;">
#     \[
#         \begin{array}{l}
#         \hline
#         \color{purple}{\textbf{Algorithm: }} \text{LOGISTIC REGRESSION GRADIENT DESCENT}(\text{data}, maxIter, \eta) \\
#         \hline
#         \textbf{1: } \mathbf{w} \leftarrow \langle 0,0,\ldots,0 \rangle \text{ or randomly initialise} \quad \textit{// initialise weights} \\
#         \textbf{2: } \textbf{for } k = 1 \ldots maxIter \textbf{ do} \\
#         \textbf{3: } \quad \textbf{for all } (x, y) \in \text{data} \textbf{ do} \\
#         \textbf{4: } \quad \quad \hat{Y}(\mathbf{x}_n) = \sigma(\mathbf{w}^T \cdot \mathbf{x}_n) \quad \textit{// compute predicted output} \\
#         \textbf{5: } \quad \quad \delta = Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n) \quad \textit{// compute scalar } \delta \\
#         \textbf{6: } \quad \quad \mathbf{w} \leftarrow \mathbf{w} + \eta \cdot \delta \cdot \hat{Y}(\mathbf{x}_n)(1 - \hat{Y}(\mathbf{x}_n)) \cdot \mathbf{x}_n \quad \textit{// update weights} \\
#         \textbf{7: } \quad \textbf{end for} \\
#         \textbf{8: } \textbf{end for} \\
#         \textbf{9: } \textbf{return } \mathbf{w} \\
#         \hline
#         \end{array}
#     \]
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 1% 50px 1% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">\(l^{(log)}\): Log Loss for Logistic Regression</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row; justify-content: center;">
#         <ul style="font-size: 28px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#             <li style="margin-bottom: 20px;">
#                 • Quite often we optimise instead of the squared loss \(l^{(sqr)}\), the log-loss \(l^{(log)}\)
#                 \[
#                     \begin{align}
#                     LL(\mathbf{w}) &= -\sum_{n} Y(\mathbf{x}_n) \cdot \log \hat{Y}(\mathbf{x}_n) + (1 - Y(\mathbf{x}_n)) \cdot \log(1 - \hat{Y}(\mathbf{x}_n)) \\
#                     \text{where } \hat{Y}(\mathbf{x}_n) &= \sigma(\mathbf{w}^T \cdot \mathbf{x}_n)
#                     \end{align}
#                 \]
#             </li>
#             <li style="margin-bottom: 20px;">
#                 • Log-loss is the natural choice for logistic regression because it comes from probability theory and has much better optimization properties (better gradients and faster learning)
#             </li>
#         </ul>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 0% 50px 0% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">\(l^{(log)}\): Log Loss for Logistic Regression</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="font-size: 18px;">
#         <h2>STEP 1: DERIVATIVE OF LOG-LOSS</h2>
#             For a single example $n$, we have:
#             $$LL_n = -Y(\mathbf{x}_n) \cdot \log \hat{Y}(\mathbf{x}_n) - (1-Y(\mathbf{x}_n)) \cdot \log(1-\hat{Y}(\mathbf{x}_n))$$
#             Let's compute $\frac{\partial LL_n}{\partial \mathbf{w}}$ using the chain rule:
#             $$\frac{\partial LL_n}{\partial \mathbf{w}} = \frac{\partial LL_n}{\partial \hat{Y}} \cdot \frac{\partial \hat{Y}}{\partial \mathbf{w}}$$
#             ---
#             <b>Part 1:</b> $\frac{\partial LL_n}{\partial \hat{Y}}$
#             $$\frac{\partial}{\partial \hat{Y}} \left[-Y \cdot \log(\hat{Y}) - (1-Y) \cdot \log(1-\hat{Y})\right]$$
#             $$= -Y \cdot \frac{1}{\hat{Y}} - (1-Y) \cdot \frac{1}{1-\hat{Y}} \cdot (-1)$$
#             $$= -\frac{Y}{\hat{Y}} + \frac{1-Y}{1-\hat{Y}}$$
#             $$= \frac{-Y(1-\hat{Y}) + (1-Y)\hat{Y}}{\hat{Y}(1-\hat{Y})}$$
#             $$= \frac{-Y + Y\hat{Y} + \hat{Y} - Y\hat{Y}}{\hat{Y}(1-\hat{Y})}$$
#             $$= \frac{\hat{Y} - Y}{\hat{Y}(1-\hat{Y})}$$
#             ---
#             <b>Part 2:</b> $\frac{\partial \hat{Y}}{\partial \mathbf{w}}$ where $\hat{Y} = \sigma(\mathbf{w}^T \cdot \mathbf{x})$
#             We need the derivative of the sigmoid:
#             $$\frac{\partial \sigma(z)}{\partial z} = \sigma(z)(1 - \sigma(z))$$
#             So by chain rule:
#             $$\frac{\partial \hat{Y}}{\partial \mathbf{w}} = \frac{\partial \sigma(\mathbf{w}^T \cdot \mathbf{x})}{\partial \mathbf{w}}$$
#             $$= \sigma(\mathbf{w}^T \cdot \mathbf{x})(1-\sigma(\mathbf{w}^T \cdot \mathbf{x})) \cdot \frac{\partial (\mathbf{w}^T \cdot \mathbf{x})}{\partial \mathbf{w}}$$
#             $$= \hat{Y}(1-\hat{Y}) \cdot \mathbf{x}$$
#             ---
#             <b>Part 3:</b> Combine them
#             $$\frac{\partial LL_n}{\partial \mathbf{w}} = \frac{\partial LL_n}{\partial \hat{Y}} \cdot \frac{\partial \hat{Y}}{\partial \mathbf{w}}$$
#             $$= \frac{\hat{Y} - Y}{\hat{Y}(1-\hat{Y})} \cdot \hat{Y}(1-\hat{Y}) \cdot \mathbf{x}$$
#             $$= (\hat{Y} - Y) \cdot \mathbf{x} \quad$$
#             $$= -(Y - \hat{Y}) \cdot \mathbf{x}$$
#             $$= -\delta \cdot \mathbf{x} \quad \text{where } \delta = Y - \hat{Y}$$
#             <div style="background-color: #ffffcc; padding: 15px; border-left: 5px solid #ffcc00; margin: 20px 0;">
#             The sigmoid derivative $\hat{Y}(1-\hat{Y})$ perfectly cancels with the denominator from the log derivative! This is why log-loss works well with sigmoid.
#             </div>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; padding: 1% 50px 1% 50px;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 30px; text-align: center;">
#         <div style="position: absolute; top: 10px; right: 10px;">
#             <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;">
#         </div>
#     </div>
#     <h1 style="font-size: 72px; font-weight: 700; margin-left: 10px; color: #333;">\(l^{(log)}\): Log Loss for Logistic Regression</h1>
#     <hr style="width: 50%; margin-left: -0%; margin-top: -0%;" />
#     <div style="display: flex; flex-direction: row; justify-content: center;">
#         <ul style="font-size: 28px; line-height: 1.8; list-style: none; padding: 0; margin-top: 40px;">
#             <li style="margin-bottom: 20px;">
#                 • The gradient wrt \(w\) are
#                 \[
# \nabla_{\mathbf{w}} LL(\mathbf{w}) = -\sum_{n} \delta \cdot \mathbf{x}_n, \text{ where } \delta = Y(\mathbf{x}_n) - \hat{Y}(\mathbf{x}_n)
#                 \]
#                 which brings us back to the familiar weight updates:
#                 \[
#                     \mathbf{w} \leftarrow \mathbf{w} + \eta \cdot \delta \cdot \mathbf{x}_n
#                 \]
#             </li>
#         </ul>
#     </div>
#     <div style="position: absolute; bottom: 20px; left: 50%; transform: translateX(-50%); font-size: 24px; color: #666;">10</div>
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 60px; text-align: center;">&nbsp;</div>
# </div>

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Worked-out Example</h1>
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Read Emails</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %%
import pandas as pd

# Create the DataFrame
df = pd.DataFrame({
    'Thread': ['old', 'new', 'new'],
    'Length': ['long', 'short', 'long'],
    'Where': ['work', 'work', 'home'],
    'Action': ['skip', 'skip', 'read']
}, index=['E1', 'E2', 'E3'])

df.index.name = 'Ex'

# Display the DataFrame
display(df)
# Out:
#    Thread Length Where Action
# Ex
# E1    old   long  work   skip
# E2    new  short  work   skip
# E3    new   long  home   read

# %%
import pandas as pd

# Create the vectorized DataFrame
df_vectorized = pd.DataFrame({
    'Thread': [0, 1, 1],
    'Length': [0, 1, 0],
    'Where': [0, 0, 1],
    'Output': [0, 0, 1]
}, index=['E1', 'E2', 'E3'])

df_vectorized.index.name = 'Ex'

display(df_vectorized)
# Out:
#     Thread  Length  Where  Output
# Ex
# E1       0       0      0       0
# E2       1       1      0       0
# E3       1       0      1       1

# %%
import pandas as pd
import numpy as np

# Add bias term (w0)
X = df_vectorized[['Thread', 'Length', 'Where']].values
X_with_bias = np.column_stack([np.ones(len(X)), X])
y = df_vectorized['Output'].values

print("\n" + "="*70)
print("LEARNING THE FUNCTION")
print("="*70)
print("\nWe want to learn:")
print("  f(thread, length, where) = σ(w₀ + w₁·thread + w₂·length + w₃·where)")
print("\nMinimise SSE (squared loss) or log-loss")
print()
# Out:
# ...
# LEARNING THE FUNCTION
# ...
#
# We want to learn:
#   f(thread, length, where) = σ(w₀ + w₁·thread + w₂·length + w₃·where)
#
# Minimise SSE (squared loss) or log-loss

# %%
# Initialize weights
w = np.array([0.4, -0.7, -0.9, 1.2])
print(f"Initialize weights: w = {w}")
print(f"  w₀ (bias) = {w[0]}")
print(f"  w₁ (Thread) = {w[1]}")
print(f"  w₂ (Length) = {w[2]}")
print(f"  w₃ (Where) = {w[3]}")
# Out:
# Initialize weights: w = [ 0.4 -0.7 -0.9  1.2]
#   w₀ (bias) = 0.4
#   w₁ (Thread) = -0.7
#   w₂ (Length) = -0.9
#   w₃ (Where) = 1.2

# %%
print("\n" + "="*70)
print("MAKING PREDICTIONS")
print("="*70)
print("\nHow to predict class based on output:")
print("  If σ(w^T·x) ≥ 0.5 → predict 1 (read)")
print("  If σ(w^T·x) < 0.5 → predict 0 (skip)")
print()

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Make predictions
results = []
for i, ex in enumerate(['E1', 'E2', 'E3']):
    x = X_with_bias[i]
    raw_score = np.dot(w, x)
    prob = sigmoid(raw_score)
    predicted = 1 if prob >= 0.5 else 0
    gold = y[i]
    delta = gold - prob
    sse = delta ** 2
    
    results.append({
        'Ex': ex,
        'Thread': X[i, 0],
        'Length': X[i, 1],
        'Where': X[i, 2],
        'Output (Predicted / Gold)': f'f({raw_score:.1f}) = {prob:.2f} / {gold}',
        'δ': f'{delta:.2f}',
        'SSE': f'{sse:.3f}'
    })

df_results = pd.DataFrame(results).set_index('Ex')
display(df_results)
# Out:
# ...
# MAKING PREDICTIONS
# ...
#
# How to predict class based on output:
#   If σ(w^T·x) ≥ 0.5 → predict 1 (read)
#   If σ(w^T·x) < 0.5 → predict 0 (skip)
#     Thread  Length  Where Output (Predicted / Gold)      δ    SSE
# Ex
# E1       0       0      0         f(0.4) = 0.60 / 0  -0.60  0.358
# E2       1       1      0        f(-1.2) = 0.23 / 0  -0.23  0.054
# E3       1       0      1         f(0.9) = 0.71 / 1   0.29  0.084

# %%
print("\n" + "="*70)
print("DETAILED CALCULATIONS")
print("="*70)

for i, ex in enumerate(['E1', 'E2', 'E3']):
    x = X_with_bias[i]
    raw_score = np.dot(w, x)
    prob = sigmoid(raw_score)
    predicted = 1 if prob >= 0.5 else 0
    gold = y[i]
    delta = gold - prob
    sse = delta ** 2
    
    print(f"\n{ex}: x = [1, {X[i,0]}, {X[i,1]}, {X[i,2]}] (with bias)")
    print(f"  Raw score: w^T·x = {w[0]}×1 + {w[1]}×{X[i,0]} + {w[2]}×{X[i,1]} + {w[3]}×{X[i,2]}")
    print(f"            = {raw_score:.2f}")
    print(f"  Probability: σ({raw_score:.2f}) = {prob:.3f}")
    print(f"  Predicted class: {predicted} ({'read' if predicted == 1 else 'skip'})")
    print(f"  True class: {gold} ({'read' if gold == 1 else 'skip'})")
    print(f"  Error (δ): {gold} - {prob:.3f} = {delta:.3f}")
    print(f"  Squared error: ({delta:.3f})² = {sse:.4f}")

total_sse = np.sum((y - sigmoid(X_with_bias @ w))**2)
print(f"\n{'='*70}")
print(f"Total SSE = {total_sse:.4f}")
print(f"{'='*70}")
# Out:
# ...
# DETAILED CALCULATIONS
# ...
#
# E1: x = [1, 0, 0, 0] (with bias)
#   Raw score: w^T·x = 0.4×1 + -0.7×0 + -0.9×0 + 1.2×0
#             = 0.40
#   Probability: σ(0.40) = 0.599
#   Predicted class: 1 (read)
#   True class: 0 (skip)
#   Error (δ): 0 - 0.599 = -0.599
#   Squared error: (-0.599)² = 0.3584
#
# E2: x = [1, 1, 1, 0] (with bias)
#   Raw score: w^T·x = 0.4×1 + -0.7×1 + -0.9×1 + 1.2×0
#             = -1.20
#   Probability: σ(-1.20) = 0.231
#   Predicted class: 0 (skip)
#   True class: 0 (skip)
#   Error (δ): 0 - 0.231 = -0.231
#   Squared error: (-0.231)² = 0.0536
#
# E3: x = [1, 1, 0, 1] (with bias)
#   Raw score: w^T·x = 0.4×1 + -0.7×1 + -0.9×0 + 1.2×1
#             = 0.90
#   Probability: σ(0.90) = 0.711
#   Predicted class: 1 (read)
#   True class: 1 (read)
#   Error (δ): 1 - 0.711 = 0.289
#   Squared error: (0.289)² = 0.0836
#
# ...
# Total SSE = 0.4956
# ...

# %% [markdown]
# <div style="height: 100vh !important; min-height: 100%; display: flex !important; justify-content: center !important; align-items: center !important; padding: 10% 0 10% 0; background-color: #0C1F2D; background: url('images/bg.jpg') center center / cover no-repeat !important;">
#     <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 80px; text-align: center;">
#         <div style="position: absolute; top: 20px; right: 20px;">
#             <!-- <img src="images/logo.png" alt="Heriot-Watt University" style="height: 80px;"> -->
#         </div>
#     </div>
#     <div style="margin: 0 auto; text-align: center;">
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Worked-out Example</h1>
#         <h1 style="text-align: center; font-size: 72px; font-weight: 700; color: white;">Customer Transactions</h1>
#         <div style="display: flex; flex-direction: column; align-items: center; justify-content: center; height: 100px; text-align: center;">
#             &nbsp;
#         </div>
#     </div>
#     <!-- <span style="position: absolute; bottom: 25px; right: 25px; font-size: 12px; color: lightgrey;">Image by <a href="https://pixabay.com/users/thedigitalartist-202249/?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pete Linforth</a> from <a href="https://pixabay.com//?utm_source=link-attribution&utm_medium=referral&utm_campaign=image&utm_content=6228020">Pixabay</a></span> -->
# </div>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
import matplotlib.pyplot as plt

print("="*70)
print("COMPARING LINEAR VS LOGISTIC REGRESSION")
print("="*70)

data = pd.DataFrame({
    'Music DL?': [0, 1, 1, 1, 0, 0, 0, 0, 1, 1],
    'Music Stream?': [1, 0, 0, 0, 1, 1, 0, 1, 1, 1],
    'Online Games': [1, 0, 1, 0, 0, 0, 1, 1, 0, 1],
    'Output': [1, 0, 1, 0, 0, 0, 1, 0, 0, 1]
}, index=[f'T{i}' for i in range(1, 11)])

print("\nTraining Data:")
display(data)

X = data.iloc[:, :-1].values
y = data['Output'].values
# Out:
# ...
# COMPARING LINEAR VS LOGISTIC REGRESSION
# ...
#
# Training Data:
#      Music DL?  Music Stream?  Online Games  Output
# T1           0              1             1       1
# T2           1              0             0       0
# T3           1              0             1       1
# T4           1              0             0       0
# T5           0              1             0       0
# T6           0              1             0       0
# T7           0              0             1       1
# T8           0              1             1       0
# T9           1              1             0       0
# T10          1              1             1       1

# %%
print("\n" + "="*70)
print("METHOD 1: LINEAR REGRESSION")
print("="*70)

# Train linear regression
lr = LinearRegression()
lr.fit(X, y)

# Get predictions
y_pred_linear = lr.predict(X)

# Create results table
results_linear = pd.DataFrame({
    'Transaction': [f'T{i}' for i in range(1, 11)],
    'Actual': y,
    'Predicted': y_pred_linear.round(3),
    'Error': (y - y_pred_linear).round(3)
})

print("\nLinear Regression Results:")
display(results_linear)

print("\n" + "="*70)
print("LEARNED FUNCTION (Linear Regression):")
print("="*70)
print(f"\nBuys = f(musicDown, musicStream, onlineGames)")
print(f"     = {lr.intercept_:.3f}")
print(f"       {lr.coef_[0]:+.3f} * musicDown")
print(f"       {lr.coef_[1]:+.3f} * musicStream")
print(f"       {lr.coef_[2]:+.3f} * onlineGames")

print("\n" + "-"*70)
print("INTERPRETATION:")
print("-"*70)
print(f"• Bias (intercept): {lr.intercept_:.3f}")
print(f"• Music Download: {lr.coef_[0]:.3f} (tiny positive effect)")
print(f"• Music Streaming: {lr.coef_[1]:.3f} (negative - reduces buying)")
print(f"• Online Games: {lr.coef_[2]:.3f} (strong positive - increases buying)")

print("\n" + "-"*70)
print("PROBLEM WITH LINEAR REGRESSION:")
print("-"*70)
print(f"• Predictions range from {y_pred_linear.min():.3f} to {y_pred_linear.max():.3f}")
print(f"• These are NOT probabilities (not bounded to [0,1])")
print(f"• Some predictions are negative or > 1")
# Out:
# ...
# METHOD 1: LINEAR REGRESSION
# ...
#
# Linear Regression Results:
#   Transaction  Actual  Predicted  Error
# 0          T1       1      0.706  0.294
# 1          T2       0      0.118 -0.118
# 2          T3       1      0.941  0.059
# 3          T4       0      0.118 -0.118
# 4          T5       0     -0.118  0.118
# 5          T6       0     -0.118  0.118
# 6          T7       1      0.824  0.176
# 7          T8       0      0.706 -0.706
# 8          T9       0     -0.000  0.000
# 9         T10       1      0.824  0.176
# ...
# LEARNED FUNCTION (Linear Regression):
# ...
#
# Buys = f(musicDown, musicStream, onlineGames)
#      = 0.000
#        +0.118 * musicDown
#        -0.118 * musicStream
#        +0.824 * onlineGames
#
# ----------------------------------------------------------------------
# INTERPRETATION:
# ----------------------------------------------------------------------
# • Bias (intercept): 0.000
# • Music Download: 0.118 (tiny positive effect)
# ...

# %%
print("\n" + "="*70)
print("METHOD 2: LOGISTIC REGRESSION")
print("="*70)

# Train logistic regression
logreg = LogisticRegression(penalty=None, max_iter=10000, solver='lbfgs')
logreg.fit(X, y)

# Get probability predictions
y_pred_logistic_prob = logreg.predict_proba(X)[:, 1]
y_pred_logistic_class = logreg.predict(X)

# Create results table
results_logistic = pd.DataFrame({
    'Transaction': [f'T{i}' for i in range(1, 11)],
    'Actual': y,
    'Probability': y_pred_logistic_prob.round(3),
    'Predicted Class': y_pred_logistic_class
})

print("\nLogistic Regression Results:")
display(results_logistic)

# Display the learned function
print("\n" + "="*70)
print("LEARNED FUNCTION (Logistic Regression):")
print("="*70)
print(f"\nBuys = f(musicDown, musicStream, onlineGames)")
print(f"     = {logreg.intercept_[0]:.4f}")
print(f"       {logreg.coef_[0][0]:+.4f} * musicDown")
print(f"       {logreg.coef_[0][1]:+.4f} * musicStream")
print(f"       {logreg.coef_[0][2]:+.4f} * onlineGames")

print("\n" + "-"*70)
print("INTERPRETATION:")
print("-"*70)

coef_dict = {
    'Music Download': logreg.coef_[0][0],
    'Music Streaming': logreg.coef_[0][1],
    'Online Games': logreg.coef_[0][2]
}

print(f"• Bias (intercept): {logreg.intercept_[0]:.4f}\n")

for feature, coef in coef_dict.items():
    direction = "increases" if coef > 0 else "decreases"
    magnitude = abs(coef)
    strength = "strong" if magnitude > 10 else "moderate" if magnitude > 1 else "weak"
    
    print(f"• {feature}: {coef:.4f}")
    print(f"  → {direction} probability (coefficient is {coef:+.4f})")
    print(f"  → {strength} effect (|{magnitude:.4f}|)\n")

strongest_feature = max(coef_dict, key=lambda k: abs(coef_dict[k]))
print(f"Strongest predictor: {strongest_feature} (|{abs(coef_dict[strongest_feature]):.4f}|)")

print("\n" + "-"*70)
print("ADVANTAGES OF LOGISTIC REGRESSION:")
print("-"*70)
print(f"• All predictions are probabilities between 0 and 1")
print(f"• Range: {y_pred_logistic_prob.min():.3f} to {y_pred_logistic_prob.max():.3f}")
print(f"• Can interpret as probability of buying")
print(f"• Weights are much larger (more sensitive to features)")
# Out:
# ...
# METHOD 2: LOGISTIC REGRESSION
# ...
#
# Logistic Regression Results:
#   Transaction  Actual  Probability  Predicted Class
# 0          T1       1        0.500                1
# 1          T2       0        0.000                0
# 2          T3       1        1.000                1
# 3          T4       0        0.000                0
# 4          T5       0        0.000                0
# 5          T6       0        0.000                0
# 6          T7       1        0.999                1
# 7          T8       0        0.500                1
# 8          T9       0        0.000                0
# 9         T10       1        1.000                1
# ...
# LEARNED FUNCTION (Logistic Regression):
# ...
#
# Buys = f(musicDown, musicStream, onlineGames)
#      = -20.9385
#        +10.7520 * musicDown
#        -7.2487 * musicStream
#        +28.1874 * onlineGames
#
# ----------------------------------------------------------------------
# INTERPRETATION:
# ...

# %%
print("\n" + "="*70)
print("WHY ARE THE WEIGHTS DIFFERENT?")
print("="*70)

print("""
Linear Regression weights are SMALL:
    • Designed to predict continuous values near 0 or 1
    • Direct output: w^T·x

Logistic Regression weights are LARGE:
    • Need to be transformed through sigmoid: σ(w^T·x)
    • Large weights create steeper sigmoid curves
    • This gives more confident predictions (closer to 0 or 1)

The sigmoid function "squashes" large values into [0,1]:
    • σ(-35) ≈ 0.0
    • σ(0) = 0.5
    • σ(+35) ≈ 1.0
""")

# Visualize sigmoid with different weight magnitudes
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

z = np.linspace(-10, 10, 200)
sigmoid = lambda x: 1 / (1 + np.exp(-x))

# Different weight magnitudes
for scale in [0.5, 1, 2, 5]:
    ax.plot(z, sigmoid(scale * z), linewidth=2, label=f'Weight scale = {scale}')

ax.axhline(y=0.5, color='gray', linestyle='--', alpha=0.5)
ax.axvline(x=0, color='gray', linestyle='--', alpha=0.5)
ax.set_xlabel('Raw score (w^T·x)', fontsize=13)
ax.set_ylabel('Probability σ(w^T·x)', fontsize=13)
ax.set_title('Effect of Weight Magnitude on Sigmoid', fontsize=14, weight='bold')
ax.legend(fontsize=11)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("\nLarger weights → Steeper sigmoid → More confident predictions!")
# Out:
# ...
# WHY ARE THE WEIGHTS DIFFERENT?
# ...
#
# Linear Regression weights are SMALL:
#     • Designed to predict continuous values near 0 or 1
#     • Direct output: w^T·x
#
# Logistic Regression weights are LARGE:
#     • Need to be transformed through sigmoid: σ(w^T·x)
#     • Large weights create steeper sigmoid curves
#     • This gives more confident predictions (closer to 0 or 1)
#
# The sigmoid function "squashes" large values into [0,1]:
#     • σ(-35) ≈ 0.0
#     • σ(0) = 0.5
#     • σ(+35) ≈ 1.0
# Larger weights → Steeper sigmoid → More confident predictions!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Create a cleaner, more intuitive visualization
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Values of Online Games to visualize (only valid binary values)
online_games_values = [0, 1]

# Create a finer mesh for smoother visualization
x1_range = np.linspace(-2.2, 2.2, 300)
x2_range = np.linspace(-2.2, 2.2, 300)
x1_mesh, x2_mesh = np.meshgrid(x1_range, x2_range)

for col_idx, online_games_val in enumerate(online_games_values):
    # === LINEAR REGRESSION (Top row) ===
    ax_linear = axes[0, col_idx]
    
    # Create feature matrix for the mesh
    X_mesh = np.c_[x1_mesh.ravel(), x2_mesh.ravel(), 
                   np.full(x1_mesh.ravel().shape, online_games_val)]
    
    # Get predictions
    Z_linear = lr.predict(X_mesh).reshape(x1_mesh.shape)
    
    # Show regions: f(x) < 0.5 (predict 0) vs f(x) >= 0.5 (predict 1)
    contour = ax_linear.contourf(x1_mesh, x2_mesh, Z_linear, 
                                  levels=[-1, 0.5, 2],
                                  colors=['#ffcccc', '#ccffcc'],
                                  alpha=0.7)
    
    # Draw the decision boundary line where f(x) = 0.5
    boundary = ax_linear.contour(x1_mesh, x2_mesh, Z_linear, 
                                 levels=[0.5], 
                                 colors='blue', linewidths=3)
    ax_linear.clabel(boundary, inline=True, fontsize=10, fmt='f(x)=0.5')
    
    # Plot data points
    for i in range(len(X)):
        if abs(X[i, 2] - online_games_val) < 0.15:
            color = 'darkred' if y[i] == 0 else 'darkgreen'
            marker = 'X' if y[i] == 0 else 'o'
            size = 300 if abs(X[i, 2] - online_games_val) < 0.15 else 150
            ax_linear.scatter(X[i, 0], X[i, 1], c=color, s=size, 
                            edgecolors='black', linewidth=2.5, marker=marker,
                            zorder=5, alpha=0.9)
            ax_linear.text(X[i, 0]+0.05, X[i, 1]+0.05, f'T{i+1}', 
                          fontsize=10, fontweight='bold')
    
    ax_linear.set_xlabel('Music Download', fontsize=12, fontweight='bold')
    ax_linear.set_ylabel('Music Stream', fontsize=12, fontweight='bold')
    ax_linear.set_title(f'Online Games = {online_games_val}', 
                       fontsize=13, fontweight='bold')
    ax_linear.set_xlim(-2.2, 2.2)
    ax_linear.set_ylim(-2.2, 2.2)
    ax_linear.grid(True, alpha=0.3, linestyle='--')
    
    # Add text annotations for regions
    ax_linear.text(0.05, 0.95, 'Predict: No Buy', 
                  transform=ax_linear.transAxes, fontsize=11,
                  bbox=dict(boxstyle='round', facecolor='#ffcccc', alpha=0.8),
                  verticalalignment='top')
    ax_linear.text(0.95, 0.05, 'Predict: Buy', 
                  transform=ax_linear.transAxes, fontsize=11,
                  bbox=dict(boxstyle='round', facecolor='#ccffcc', alpha=0.8),
                  verticalalignment='bottom', horizontalalignment='right')
    
    # === LOGISTIC REGRESSION (Bottom row) ===
    ax_logistic = axes[1, col_idx]
    
    # Get probability predictions
    Z_logistic = logreg.predict_proba(X_mesh)[:, 1].reshape(x1_mesh.shape)
    
    # Show regions: P < 0.5 (predict 0) vs P >= 0.5 (predict 1)
    contour = ax_logistic.contourf(x1_mesh, x2_mesh, Z_logistic, 
                                    levels=[0, 0.5, 1],
                                    colors=['#ffcccc', '#ccffcc'],
                                    alpha=0.7)
    
    # Draw the decision boundary line where P(Buys=1) = 0.5
    boundary = ax_logistic.contour(x1_mesh, x2_mesh, Z_logistic, 
                                   levels=[0.5], 
                                   colors='blue', linewidths=3)
    ax_logistic.clabel(boundary, inline=True, fontsize=10, fmt='P=0.5')
    
    # Also show probability contours
    prob_contours = ax_logistic.contour(x1_mesh, x2_mesh, Z_logistic, 
                                       levels=[0.1, 0.3, 0.7, 0.9],
                                       colors='gray', linewidths=1, 
                                       linestyles='dashed', alpha=0.4)
    ax_logistic.clabel(prob_contours, inline=True, fontsize=8)
    
    # Plot data points
    for i in range(len(X)):
        if abs(X[i, 2] - online_games_val) < 0.15:
            color = 'darkred' if y[i] == 0 else 'darkgreen'
            marker = 'X' if y[i] == 0 else 'o'
            size = 300 if abs(X[i, 2] - online_games_val) < 0.15 else 150
            ax_logistic.scatter(X[i, 0], X[i, 1], c=color, s=size, 
                              edgecolors='black', linewidth=2.5, marker=marker,
                              zorder=5, alpha=0.9)
            ax_logistic.text(X[i, 0]+0.05, X[i, 1]+0.05, f'T{i+1}', 
                           fontsize=10, fontweight='bold')
    
    ax_logistic.set_xlabel('Music Download', fontsize=12, fontweight='bold')
    ax_logistic.set_ylabel('Music Stream', fontsize=12, fontweight='bold')
    ax_logistic.set_title(f'Online Games = {online_games_val}', 
                         fontsize=13, fontweight='bold')
    ax_logistic.set_xlim(-2.2, 2.2)
    ax_logistic.set_ylim(-2.2, 2.2)
    ax_logistic.grid(True, alpha=0.3, linestyle='--')
    
    # Add text annotations for regions
    ax_logistic.text(0.05, 0.95, 'Predict: No Buy\n(P<0.5)', 
                    transform=ax_logistic.transAxes, fontsize=11,
                    bbox=dict(boxstyle='round', facecolor='#ffcccc', alpha=0.8),
                    verticalalignment='top')
    ax_logistic.text(0.95, 0.05, 'Predict: Buy\n(P≥0.5)', 
                    transform=ax_logistic.transAxes, fontsize=11,
                    bbox=dict(boxstyle='round', facecolor='#ccffcc', alpha=0.8),
                    verticalalignment='bottom', horizontalalignment='right')

# Row labels
fig.text(0.02, 0.75, 'LINEAR\nREGRESSION', 
         fontsize=14, fontweight='bold', rotation=90,
         verticalalignment='center', horizontalalignment='center')
fig.text(0.02, 0.25, 'LOGISTIC\nREGRESSION', 
         fontsize=14, fontweight='bold', rotation=90,
         verticalalignment='center', horizontalalignment='center')

# Legend
legend_elements = [
    plt.Line2D([0], [0], marker='X', color='w', markerfacecolor='darkred', 
               markersize=12, markeredgecolor='black', markeredgewidth=2, 
               label='Actual: No Buy (0)', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='darkgreen', 
               markersize=12, markeredgecolor='black', markeredgewidth=2,
               label='Actual: Buy (1)', linestyle='None'),
    plt.Line2D([0], [0], color='blue', linewidth=3, 
               label='Decision Boundary (threshold=0.5)'),
    plt.Rectangle((0,0), 1, 1, facecolor='#ffcccc', alpha=0.7, 
                  edgecolor='black', label='Predict: No Buy'),
    plt.Rectangle((0,0), 1, 1, facecolor='#ccffcc', alpha=0.7, 
                  edgecolor='black', label='Predict: Buy')
]

fig.legend(handles=legend_elements, loc='upper center', ncol=5, 
          bbox_to_anchor=(0.5, 0.98), fontsize=12, frameon=True, 
          fancybox=True, shadow=True)

plt.suptitle('Decision Boundaries: Linear vs Logistic Regression\n' + 
             'How each model splits the feature space into "Buy" vs "No Buy" regions', 
             fontsize=16, fontweight='bold', y=0.995)

plt.tight_layout(rect=[0.03, 0, 1, 0.96])
plt.show()

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('SmZmBKc7Lrs', start=130)
